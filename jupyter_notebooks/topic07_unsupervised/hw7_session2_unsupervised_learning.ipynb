# %% [markdown]
# <center>
# <img src="../../img/ods_stickers.jpg">
# ## Открытый курс по машинному обучению. Сессия № 2
# Авторы материала: Ольга Дайховская, Юрий Кашницкий. Материал распространяется на условиях лицензии [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/). Можно использовать в любых целях (редактировать, поправлять и брать за основу), кроме коммерческих, но с обязательным упоминанием автора материала.

# %% [markdown]
# # <center>Домашнее задание № 7
# ## <center> Обучение без учителя

# %% [markdown]
# В этом задании мы разберемся с тем, как работают методы снижения размерности и кластеризации данных. Заодно еще раз попрактикуемся в задаче классификации.
#
# Мы будем работать с набором данных [Samsung Human Activity Recognition](https://archive.ics.uci.edu/ml/datasets/Human+Activity+Recognition+Using+Smartphones). Скачайте данные [отсюда](https://cloud.mail.ru/public/3EJK/cB2VXsyrP). Данные поступают с акселерометров и гироскопов мобильных телефонов Samsung Galaxy S3 (подробнее про признаки – по ссылке на UCI выше), также известен вид активности человека с телефоном в кармане – ходил ли он, стоял, лежал, сидел или шел вверх/вниз по лестнице.
#
# Вначале мы представим, что вид активности нам неизвестнен, и попробуем кластеризовать людей чисто на основе имеющихся признаков. Затем решим задачу определения вида физической активности именно как задачу классификации.
#
# Заполните код в клетках (где написано "Ваш код здесь") и ответьте на вопросы в [веб-форме](https://docs.google.com/forms/d/1ga4KcJdwMWsgEeE76vcTQ34C2iLF7VMhM6nIh_BHUNE).

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm import tqdm_notebook

# %matplotlib inline
from matplotlib import pyplot as plt
plt.style.use(['seaborn-darkgrid'])
plt.rcParams['figure.figsize'] = (12, 9)
plt.rcParams['font.family'] = 'DejaVu Sans'

from sklearn import metrics
from sklearn.cluster import KMeans, AgglomerativeClustering, SpectralClustering
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC

RANDOM_STATE = 17

# %%
X_train = np.loadtxt("../../data/samsung_HAR/samsung_train.txt")
y_train = np.loadtxt("../../data/samsung_HAR/samsung_train_labels.txt").astype(int)

X_test = np.loadtxt("../../data/samsung_HAR/samsung_test.txt")
y_test = np.loadtxt("../../data/samsung_HAR/samsung_test_labels.txt").astype(int)

# %%
# Проверим размерности
assert(X_train.shape == (7352, 561) and y_train.shape == (7352,))
assert(X_test.shape == (2947, 561) and y_test.shape == (2947,))

# %% [markdown]
# Для кластеризации нам не нужен вектор ответов, поэтому будем работать с объединением обучающей и тестовой выборок. Объедините *X_train* с *X_test*, а *y_train* – с *y_test*.

# %%
# Ваш код здесь
X = np.concatenate((X_train, X_test), axis=0)
y = np.concatenate((y_train, y_test), axis=0)
print(X.shape, y.shape)
# Out:
# (10299, 561) (10299,)

# %% [markdown]
# Определим число уникальных значений меток целевого класса.

# %%
np.unique(y)
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
n_classes = np.unique(y).size

# %% [markdown]
# [Эти метки соответствуют:](https://archive.ics.uci.edu/ml/machine-learning-databases/00240/UCI%20HAR%20Dataset.names)
# - 1 - ходьбе
# - 2 - подъему вверх по лестнице
# - 3 - спуску по лестнице
# - 4 - сидению
# - 5 - стоянию
# - 6 - лежанию

# %% [markdown]
# Отмасштабируйте выборку с помощью `StandardScaler` с параметрами по умолчанию.

# %%
# Ваш код здесь
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# Понижаем размерность с помощью PCA, оставляя столько компонент, сколько нужно для того, чтобы объяснить как минимум 90% дисперсии исходных (отмасштабированных) данных. Используйте отмасштабированную выборку и зафиксируйте random_state (константа RANDOM_STATE).

# %%
from sklearn import decomposition

# %%
plt.ylim?

# %%
# Ваш код здесь
pca = decomposition.PCA(random_state=RANDOM_STATE)
X_pca = pca.fit(X_scaled)

# %% [markdown]
# **Вопрос 1:**<br>
# Какое минимальное число главных компонент нужно выделить, чтобы объяснить 90% дисперсии исходных (отмасштабированных) данных?

# %%
# Ваш код здесь
plt.figure(figsize=(5,5))
plt.plot(np.cumsum(pca.explained_variance_ratio_), color='k', lw=2)
plt.xlabel('Number of components')
plt.ylabel('Total explained variance')
plt.xlim(40, 80)
#plt.yticks(np.arange(0, 1.1, 0.1))
plt.axvline(64, c='b')
plt.axhline(0.9, c='r')
plt.show();

# %% [markdown]
# **Варианты:**
# - 56
# - **65**
# - 66
# - 193

# %% [markdown]
# **Вопрос 2:**<br>
# Сколько процентов дисперсии приходится на первую главную компоненту? Округлите до целых процентов.
#
# **Варианты:**
# - 45
# - **51**
# - 56
# - 61

# %%
for i, component in enumerate(pca.components_):
    print("{} component: {}% of initial variance".format(i + 1, 
          round(100 * pca.explained_variance_ratio_[i], 2)))
    print(" + ".join("%.3f x %s" % (value, name)
                     for value, name in zip(component,
                                            np.unique(y))))
# Out:
# 1 component: 50.74% of initial variance
# 0.000 x 1 + -0.003 x 2 + -0.002 x 3 + 0.056 x 4 + 0.057 x 5 + 0.054 x 6
# 2 component: 6.24% of initial variance
# 0.017 x 1 + 0.001 x 2 + -0.005 x 3 + -0.011 x 4 + -0.024 x 5 + -0.032 x 6
# 3 component: 2.69% of initial variance
# -0.033 x 1 + 0.002 x 2 + 0.009 x 3 + -0.026 x 4 + -0.025 x 5 + 0.042 x 6
# 4 component: 2.45% of initial variance
# 0.022 x 1 + 0.000 x 2 + -0.010 x 3 + -0.041 x 4 + -0.014 x 5 + 0.039 x 6
# 5 component: 1.89% of initial variance
# 0.001 x 1 + 0.010 x 2 + 0.003 x 3 + 0.005 x 4 + -0.010 x 5 + -0.037 x 6
# 6 component: 1.63% of initial variance
# -0.001 x 1 + 0.016 x 2 + 0.023 x 3 + -0.021 x 4 + -0.023 x 5 + -0.038 x 6
# 7 component: 1.41% of initial variance
# -0.038 x 1 + 0.008 x 2 + 0.036 x 3 + 0.050 x 4 + -0.013 x 5 + 0.038 x 6
# 8 component: 1.22% of initial variance
# -0.076 x 1 + 0.014 x 2 + 0.035 x 3 + -0.034 x 4 + 0.042 x 5 + 0.005 x 6
# 9 component: 0.99% of initial variance
# -0.072 x 1 + -0.005 x 2 + 0.020 x 3 + -0.001 x 4 + 0.012 x 5 + -0.010 x 6
# 10 component: 0.95% of initial variance
# -0.051 x 1 + -0.001 x 2 + 0.040 x 3 + -0.034 x 4 + 0.002 x 5 + 0.014 x 6
# 11 component: 0.86% of initial variance
# 0.071 x 1 + 0.007 x 2 + -0.032 x 3 + -0.015 x 4 + 0.015 x 5 + -0.015 x 6
# 12 component: 0.81% of initial variance
# 0.010 x 1 + 0.019 x 2 + 0.003 x 3 + 0.005 x 4 + -0.007 x 5 + -0.008 x 6
# 13 component: 0.77% of initial variance
# -0.055 x 1 + -0.018 x 2 + -0.019 x 3 + -0.028 x 4 + -0.001 x 5 + 0.021 x 6
# 14 component: 0.68% of initial variance
# 0.012 x 1 + 0.010 x 2 + 0.013 x 3 + 0.011 x 4 + -0.019 x 5 + 0.025 x 6
# 15 component: 0.63% of initial variance
# -0.007 x 1 + 0.023 x 2 + 0.049 x 3 + 0.015 x 4 + 0.012 x 5 + -0.004 x 6
# 16 component: 0.62% of initial variance
# 0.030 x 1 + 0.013 x 2 + -0.017 x 3 + 0.008 x 4 + -0.019 x 5 + 0.010 x 6
# 17 component: 0.6% of initial variance
# -0.018 x 1 + -0.014 x 2 + -0.000 x 3 + 0.001 x 4 + -0.011 x 5 + 0.018 x 6
# 18 component: 0.58% of initial variance
# -0.035 x 1 + 0.019 x 2 + 0.050 x 3 + 0.010 x 4 + -0.006 x 5 + 0.016 x 6
# 19 component: 0.56% of initial variance
# 0.001 x 1 + -0.006 x 2 + 0.046 x 3 + -0.005 x 4 + 0.010 x 5 + 0.016 x 6
# 20 component: 0.54% of initial variance
# 0.020 x 1 + 0.000 x 2 + -0.006 x 3 + 0.011 x 4 + 0.013 x 5 + 0.029 x 6
# 21 component: 0.52% of initial variance
# 0.041 x 1 + 0.017 x 2 + 0.003 x 3 + 0.008 x 4 + -0.026 x 5 + 0.017 x 6
# 22 component: 0.5% of initial variance
# 0.001 x 1 + 0.021 x 2 + 0.002 x 3 + -0.018 x 4 + -0.002 x 5 + -0.011 x 6
# 23 component: 0.47% of initial variance
# -0.059 x 1 + 0.007 x 2 + 0.012 x 3 + 0.002 x 4 + 0.013 x 5 + -0.018 x 6
# 24 component: 0.46% of initial variance
# 0.071 x 1 + 0.035 x 2 + -0.041 x 3 + -0.006 x 4 + 0.013 x 5 + 0.003 x 6
# 25 component: 0.45% of initial variance
# -0.043 x 1 + -0.032 x 2 + 0.042 x 3 + -0.009 x 4 + 0.013 x 5 + 0.009 x 6
# 26 component: 0.44% of initial variance
# 0.114 x 1 + 0.011 x 2 + -0.041 x 3 + -0.001 x 4 + 0.007 x 5 + -0.019 x 6
# 27 component: 0.42% of initial variance
# 0.011 x 1 + 0.029 x 2 + 0.021 x 3 + 0.026 x 4 + -0.007 x 5 + -0.013 x 6
# 28 component: 0.4% of initial variance
# -0.169 x 1 + -0.075 x 2 + 0.150 x 3 + -0.004 x 4 + -0.017 x 5 + 0.007 x 6
# 29 component: 0.39% of initial variance
# 0.001 x 1 + 0.016 x 2 + -0.028 x 3 + 0.011 x 4 + -0.001 x 5 + -0.016 x 6
# 30 component: 0.38% of initial variance
# -0.115 x 1 + 0.010 x 2 + 0.017 x 3 + 0.004 x 4 + 0.010 x 5 + -0.029 x 6
# 31 component: 0.37% of initial variance
# -0.060 x 1 + -0.041 x 2 + -0.049 x 3 + -0.011 x 4 + 0.010 x 5 + 0.010 x 6
# 32 component: 0.36% of initial variance
# 0.041 x 1 + 0.078 x 2 + -0.030 x 3 + -0.004 x 4 + 0.031 x 5 + 0.003 x 6
# 33 component: 0.35% of initial variance
# 0.006 x 1 + 0.156 x 2 + -0.077 x 3 + 0.007 x 4 + -0.020 x 5 + -0.008 x 6
# 34 component: 0.35% of initial variance
# -0.164 x 1 + -0.060 x 2 + 0.080 x 3 + 0.013 x 4 + -0.016 x 5 + -0.013 x 6
# 35 component: 0.34% of initial variance
# -0.269 x 1 + -0.114 x 2 + 0.084 x 3 + 0.008 x 4 + 0.010 x 5 + -0.003 x 6
# 36 component: 0.33% of initial variance
# -0.082 x 1 + -0.033 x 2 + 0.094 x 3 + 0.010 x 4 + 0.011 x 5 + -0.005 x 6
# 37 component: 0.32% of initial variance
# -0.010 x 1 + 0.043 x 2 + -0.037 x 3 + 0.005 x 4 + 0.003 x 5 + 0.015 x 6
# 38 component: 0.3% of initial variance
# 0.130 x 1 + 0.014 x 2 + -0.047 x 3 + 0.000 x 4 + 0.009 x 5 + 0.007 x 6
# 39 component: 0.29% of initial variance
# 0.017 x 1 + 0.070 x 2 + -0.008 x 3 + 0.006 x 4 + 0.007 x 5 + -0.011 x 6
# 40 component: 0.29% of initial variance
# 0.233 x 1 + 0.007 x 2 + -0.124 x 3 + -0.010 x 4 + 0.006 x 5 + 0.002 x 6
# 41 component: 0.28% of initial variance
# 0.030 x 1 + -0.001 x 2 + 0.038 x 3 + 0.000 x 4 + -0.012 x 5 + -0.005 x 6
# 42 component: 0.27% of initial variance
# -0.150 x 1 + 0.145 x 2 + 0.052 x 3 + -0.002 x 4 + 0.017 x 5 + -0.011 x 6
# 43 component: 0.26% of initial variance
# -0.167 x 1 + 0.205 x 2 + 0.112 x 3 + -0.007 x 4 + -0.004 x 5 + 0.008 x 6
# 44 component: 0.26% of initial variance
# 0.037 x 1 + 0.168 x 2 + 0.065 x 3 + -0.009 x 4 + 0.021 x 5 + 0.011 x 6
# 45 component: 0.26% of initial variance
# -0.024 x 1 + -0.017 x 2 + 0.028 x 3 + 0.009 x 4 + 0.009 x 5 + -0.005 x 6
# 46 component: 0.25% of initial variance
# -0.006 x 1 + 0.104 x 2 + -0.034 x 3 + -0.013 x 4 + -0.012 x 5 + -0.001 x 6
# 47 component: 0.25% of initial variance
# -0.063 x 1 + -0.017 x 2 + -0.121 x 3 + 0.010 x 4 + -0.001 x 5 + 0.010 x 6
# 48 component: 0.24% of initial variance
# -0.013 x 1 + -0.050 x 2 + 0.003 x 3 + -0.009 x 4 + 0.047 x 5 + 0.015 x 6
# 49 component: 0.24% of initial variance
# 0.053 x 1 + 0.001 x 2 + 0.012 x 3 + -0.013 x 4 + 0.006 x 5 + 0.030 x 6
# 50 component: 0.23% of initial variance
# 0.069 x 1 + -0.062 x 2 + 0.188 x 3 + 0.006 x 4 + 0.020 x 5 + 0.010 x 6
# 51 component: 0.23% of initial variance
# -0.039 x 1 + 0.142 x 2 + -0.058 x 3 + -0.009 x 4 + -0.006 x 5 + 0.000 x 6
# 52 component: 0.22% of initial variance
# 0.072 x 1 + -0.015 x 2 + 0.128 x 3 + 0.001 x 4 + 0.021 x 5 + -0.018 x 6
# 53 component: 0.21% of initial variance
# -0.062 x 1 + -0.265 x 2 + -0.059 x 3 + -0.003 x 4 + 0.007 x 5 + 0.011 x 6
# 54 component: 0.21% of initial variance
# 0.004 x 1 + 0.034 x 2 + -0.150 x 3 + -0.002 x 4 + 0.000 x 5 + -0.002 x 6
# 55 component: 0.2% of initial variance
# 0.005 x 1 + 0.008 x 2 + -0.457 x 3 + 0.009 x 4 + 0.010 x 5 + -0.009 x 6
# 56 component: 0.2% of initial variance
# 0.060 x 1 + 0.299 x 2 + 0.149 x 3 + -0.003 x 4 + 0.002 x 5 + -0.015 x 6
# 57 component: 0.2% of initial variance
# -0.010 x 1 + 0.030 x 2 + -0.277 x 3 + 0.005 x 4 + -0.007 x 5 + -0.011 x 6
# 58 component: 0.19% of initial variance
# -0.056 x 1 + -0.139 x 2 + 0.072 x 3 + 0.001 x 4 + 0.021 x 5 + -0.023 x 6
# 59 component: 0.19% of initial variance
# -0.062 x 1 + -0.317 x 2 + -0.065 x 3 + 0.001 x 4 + -0.001 x 5 + 0.010 x 6
# 60 component: 0.19% of initial variance
# -0.042 x 1 + 0.013 x 2 + -0.071 x 3 + 0.010 x 4 + -0.011 x 5 + 0.022 x 6
# 61 component: 0.19% of initial variance
# -0.013 x 1 + -0.008 x 2 + 0.004 x 3 + 0.002 x 4 + -0.001 x 5 + 0.012 x 6
# 62 component: 0.18% of initial variance
# 0.015 x 1 + 0.019 x 2 + -0.035 x 3 + -0.010 x 4 + -0.010 x 5 + 0.012 x 6
# 63 component: 0.18% of initial variance
# -0.076 x 1 + -0.135 x 2 + -0.143 x 3 + 0.002 x 4 + 0.012 x 5 + -0.017 x 6
# 64 component: 0.18% of initial variance
# 0.058 x 1 + 0.126 x 2 + -0.061 x 3 + 0.007 x 4 + -0.010 x 5 + -0.009 x 6
# 65 component: 0.17% of initial variance
# -0.056 x 1 + -0.247 x 2 + 0.089 x 3 + 0.005 x 4 + -0.017 x 5 + 0.012 x 6
# 66 component: 0.17% of initial variance
# -0.034 x 1 + 0.096 x 2 + -0.125 x 3 + -0.007 x 4 + 0.014 x 5 + 0.024 x 6
# 67 component: 0.17% of initial variance
# 0.013 x 1 + -0.006 x 2 + -0.063 x 3 + -0.016 x 4 + 0.000 x 5 + -0.006 x 6
# 68 component: 0.17% of initial variance
# -0.049 x 1 + -0.255 x 2 + 0.053 x 3 + -0.014 x 4 + -0.010 x 5 + -0.014 x 6
# 69 component: 0.16% of initial variance
# 0.063 x 1 + 0.197 x 2 + -0.098 x 3 + -0.000 x 4 + -0.014 x 5 + 0.012 x 6
# 70 component: 0.16% of initial variance
# -0.047 x 1 + 0.142 x 2 + -0.047 x 3 + -0.002 x 4 + 0.007 x 5 + -0.005 x 6
# 71 component: 0.16% of initial variance
# -0.045 x 1 + 0.055 x 2 + 0.012 x 3 + -0.001 x 4 + 0.014 x 5 + -0.008 x 6
# 72 component: 0.16% of initial variance
# 0.013 x 1 + 0.046 x 2 + -0.017 x 3 + -0.001 x 4 + 0.017 x 5 + -0.020 x 6
# 73 component: 0.15% of initial variance
# 0.080 x 1 + -0.084 x 2 + 0.013 x 3 + 0.013 x 4 + -0.000 x 5 + -0.006 x 6
# 74 component: 0.15% of initial variance
# -0.102 x 1 + 0.037 x 2 + -0.054 x 3 + 0.003 x 4 + 0.008 x 5 + 0.001 x 6
# 75 component: 0.15% of initial variance
# -0.057 x 1 + 0.037 x 2 + -0.071 x 3 + -0.008 x 4 + -0.015 x 5 + -0.005 x 6
# 76 component: 0.14% of initial variance
# 0.002 x 1 + -0.124 x 2 + 0.060 x 3 + 0.001 x 4 + -0.001 x 5 + -0.005 x 6
# 77 component: 0.14% of initial variance
# 0.039 x 1 + -0.068 x 2 + 0.060 x 3 + -0.023 x 4 + -0.013 x 5 + -0.015 x 6
# 78 component: 0.14% of initial variance
# 0.118 x 1 + -0.027 x 2 + -0.106 x 3 + -0.001 x 4 + 0.010 x 5 + 0.013 x 6
# 79 component: 0.14% of initial variance
# 0.097 x 1 + -0.122 x 2 + -0.016 x 3 + -0.004 x 4 + -0.000 x 5 + 0.004 x 6
# 80 component: 0.14% of initial variance
# -0.040 x 1 + -0.081 x 2 + 0.012 x 3 + 0.004 x 4 + 0.009 x 5 + 0.031 x 6
# 81 component: 0.13% of initial variance
# 0.024 x 1 + -0.136 x 2 + -0.069 x 3 + -0.010 x 4 + 0.000 x 5 + -0.007 x 6
# 82 component: 0.13% of initial variance
# -0.008 x 1 + -0.042 x 2 + 0.250 x 3 + -0.010 x 4 + 0.010 x 5 + 0.008 x 6
# 83 component: 0.13% of initial variance
# 0.017 x 1 + 0.022 x 2 + 0.258 x 3 + 0.009 x 4 + 0.001 x 5 + 0.005 x 6
# 84 component: 0.13% of initial variance
# -0.041 x 1 + -0.032 x 2 + -0.005 x 3 + -0.007 x 4 + -0.013 x 5 + 0.002 x 6
# 85 component: 0.13% of initial variance
# 0.044 x 1 + -0.024 x 2 + 0.028 x 3 + -0.002 x 4 + -0.020 x 5 + -0.002 x 6
# 86 component: 0.12% of initial variance
# -0.101 x 1 + -0.035 x 2 + -0.003 x 3 + 0.007 x 4 + -0.012 x 5 + -0.007 x 6
# 87 component: 0.12% of initial variance
# 0.055 x 1 + -0.047 x 2 + -0.011 x 3 + -0.011 x 4 + 0.021 x 5 + -0.022 x 6
# 88 component: 0.12% of initial variance
# 0.025 x 1 + 0.039 x 2 + -0.011 x 3 + 0.009 x 4 + 0.008 x 5 + 0.013 x 6
# 89 component: 0.12% of initial variance
# 0.049 x 1 + 0.101 x 2 + 0.058 x 3 + -0.026 x 4 + 0.011 x 5 + 0.002 x 6
# 90 component: 0.12% of initial variance
# 0.103 x 1 + 0.115 x 2 + 0.128 x 3 + 0.012 x 4 + -0.008 x 5 + 0.004 x 6
# 91 component: 0.11% of initial variance
# 0.037 x 1 + 0.147 x 2 + 0.113 x 3 + -0.016 x 4 + -0.010 x 5 + -0.002 x 6
# 92 component: 0.11% of initial variance
# 0.018 x 1 + -0.016 x 2 + -0.096 x 3 + -0.010 x 4 + -0.012 x 5 + 0.015 x 6
# 93 component: 0.11% of initial variance
# 0.019 x 1 + 0.005 x 2 + 0.048 x 3 + 0.008 x 4 + -0.001 x 5 + -0.007 x 6
# 94 component: 0.11% of initial variance
# 0.016 x 1 + 0.055 x 2 + 0.083 x 3 + -0.007 x 4 + -0.005 x 5 + 0.006 x 6
# 95 component: 0.11% of initial variance
# 0.001 x 1 + 0.007 x 2 + 0.006 x 3 + 0.008 x 4 + 0.008 x 5 + -0.010 x 6
# 96 component: 0.11% of initial variance
# 0.027 x 1 + 0.041 x 2 + 0.037 x 3 + 0.003 x 4 + 0.006 x 5 + -0.004 x 6
# 97 component: 0.1% of initial variance
# 0.016 x 1 + 0.044 x 2 + 0.001 x 3 + 0.004 x 4 + -0.002 x 5 + 0.006 x 6
# 98 component: 0.1% of initial variance
# 0.004 x 1 + 0.013 x 2 + 0.022 x 3 + -0.003 x 4 + -0.018 x 5 + 0.005 x 6
# 99 component: 0.1% of initial variance
# 0.014 x 1 + 0.030 x 2 + 0.040 x 3 + -0.000 x 4 + -0.004 x 5 + -0.002 x 6
# 100 component: 0.1% of initial variance
# -0.037 x 1 + -0.016 x 2 + 0.001 x 3 + -0.006 x 4 + 0.025 x 5 + -0.007 x 6
# 101 component: 0.1% of initial variance
# 0.050 x 1 + -0.034 x 2 + -0.019 x 3 + 0.003 x 4 + -0.009 x 5 + -0.014 x 6
# 102 component: 0.09% of initial variance
# -0.031 x 1 + 0.063 x 2 + -0.005 x 3 + 0.005 x 4 + -0.017 x 5 + -0.007 x 6
# 103 component: 0.09% of initial variance
# -0.014 x 1 + -0.008 x 2 + 0.026 x 3 + 0.012 x 4 + -0.010 x 5 + -0.015 x 6
# 104 component: 0.09% of initial variance
# -0.026 x 1 + 0.059 x 2 + 0.010 x 3 + -0.009 x 4 + 0.002 x 5 + 0.006 x 6
# 105 component: 0.09% of initial variance
# -0.018 x 1 + 0.004 x 2 + -0.052 x 3 + -0.002 x 4 + 0.000 x 5 + -0.000 x 6
# 106 component: 0.09% of initial variance
# -0.012 x 1 + 0.080 x 2 + 0.001 x 3 + 0.004 x 4 + 0.010 x 5 + 0.019 x 6
# 107 component: 0.09% of initial variance
# 0.030 x 1 + -0.012 x 2 + -0.047 x 3 + 0.004 x 4 + -0.023 x 5 + 0.002 x 6
# 108 component: 0.09% of initial variance
# 0.063 x 1 + -0.028 x 2 + 0.055 x 3 + 0.012 x 4 + -0.014 x 5 + -0.027 x 6
# 109 component: 0.09% of initial variance
# 0.047 x 1 + -0.002 x 2 + 0.017 x 3 + 0.009 x 4 + -0.004 x 5 + -0.016 x 6
# 110 component: 0.08% of initial variance
# 0.055 x 1 + 0.012 x 2 + 0.071 x 3 + -0.011 x 4 + -0.005 x 5 + -0.014 x 6
# 111 component: 0.08% of initial variance
# 0.025 x 1 + 0.016 x 2 + 0.046 x 3 + 0.003 x 4 + -0.005 x 5 + -0.013 x 6
# 112 component: 0.08% of initial variance
# 0.003 x 1 + 0.031 x 2 + -0.003 x 3 + 0.008 x 4 + 0.006 x 5 + 0.017 x 6
# 113 component: 0.08% of initial variance
# 0.034 x 1 + -0.023 x 2 + 0.022 x 3 + -0.011 x 4 + -0.009 x 5 + 0.011 x 6
# 114 component: 0.08% of initial variance
# 0.038 x 1 + -0.035 x 2 + 0.011 x 3 + -0.012 x 4 + 0.032 x 5 + 0.015 x 6
# 115 component: 0.08% of initial variance
# -0.006 x 1 + 0.001 x 2 + -0.029 x 3 + 0.019 x 4 + -0.003 x 5 + 0.011 x 6
# 116 component: 0.08% of initial variance
# 0.024 x 1 + 0.050 x 2 + 0.011 x 3 + 0.002 x 4 + 0.001 x 5 + -0.011 x 6
# 117 component: 0.07% of initial variance
# -0.027 x 1 + 0.039 x 2 + -0.048 x 3 + 0.013 x 4 + 0.009 x 5 + 0.008 x 6
# 118 component: 0.07% of initial variance
# -0.103 x 1 + 0.043 x 2 + 0.002 x 3 + -0.006 x 4 + 0.011 x 5 + 0.018 x 6
# 119 component: 0.07% of initial variance
# 0.035 x 1 + 0.014 x 2 + 0.029 x 3 + 0.006 x 4 + -0.004 x 5 + -0.003 x 6
# 120 component: 0.07% of initial variance
# -0.012 x 1 + 0.013 x 2 + -0.008 x 3 + -0.003 x 4 + 0.012 x 5 + -0.020 x 6
# 121 component: 0.07% of initial variance
# -0.012 x 1 + 0.033 x 2 + 0.004 x 3 + -0.009 x 4 + -0.001 x 5 + -0.004 x 6
# 122 component: 0.07% of initial variance
# 0.016 x 1 + 0.025 x 2 + 0.026 x 3 + 0.004 x 4 + -0.001 x 5 + -0.003 x 6
# 123 component: 0.07% of initial variance
# 0.028 x 1 + 0.018 x 2 + -0.004 x 3 + -0.001 x 4 + -0.001 x 5 + -0.002 x 6
# 124 component: 0.07% of initial variance
# 0.041 x 1 + -0.028 x 2 + 0.019 x 3 + 0.003 x 4 + -0.017 x 5 + 0.008 x 6
# 125 component: 0.06% of initial variance
# -0.096 x 1 + 0.042 x 2 + -0.059 x 3 + 0.009 x 4 + -0.009 x 5 + 0.003 x 6
# 126 component: 0.06% of initial variance
# -0.028 x 1 + 0.030 x 2 + 0.007 x 3 + -0.009 x 4 + -0.011 x 5 + 0.025 x 6
# 127 component: 0.06% of initial variance
# 0.116 x 1 + -0.052 x 2 + -0.018 x 3 + 0.003 x 4 + -0.001 x 5 + -0.002 x 6
# 128 component: 0.06% of initial variance
# -0.013 x 1 + 0.010 x 2 + -0.013 x 3 + 0.006 x 4 + -0.002 x 5 + 0.013 x 6
# 129 component: 0.06% of initial variance
# 0.019 x 1 + -0.013 x 2 + 0.035 x 3 + 0.010 x 4 + -0.016 x 5 + 0.015 x 6
# 130 component: 0.06% of initial variance
# 0.193 x 1 + -0.050 x 2 + 0.047 x 3 + -0.007 x 4 + 0.004 x 5 + -0.006 x 6
# 131 component: 0.06% of initial variance
# 0.067 x 1 + 0.051 x 2 + 0.033 x 3 + -0.002 x 4 + -0.001 x 5 + 0.002 x 6
# 132 component: 0.06% of initial variance
# 0.010 x 1 + 0.032 x 2 + -0.017 x 3 + -0.007 x 4 + -0.014 x 5 + -0.002 x 6
# 133 component: 0.06% of initial variance
# 0.112 x 1 + -0.034 x 2 + 0.052 x 3 + 0.002 x 4 + -0.020 x 5 + -0.002 x 6
# 134 component: 0.06% of initial variance
# 0.214 x 1 + -0.121 x 2 + 0.055 x 3 + -0.009 x 4 + -0.004 x 5 + 0.004 x 6
# 135 component: 0.05% of initial variance
# -0.153 x 1 + 0.035 x 2 + -0.013 x 3 + -0.010 x 4 + 0.007 x 5 + -0.009 x 6
# 136 component: 0.05% of initial variance
# 0.141 x 1 + -0.031 x 2 + 0.006 x 3 + 0.004 x 4 + -0.003 x 5 + -0.002 x 6
# 137 component: 0.05% of initial variance
# -0.054 x 1 + 0.026 x 2 + 0.007 x 3 + -0.001 x 4 + 0.001 x 5 + -0.004 x 6
# 138 component: 0.05% of initial variance
# 0.153 x 1 + -0.009 x 2 + 0.028 x 3 + 0.004 x 4 + 0.016 x 5 + 0.004 x 6
# 139 component: 0.05% of initial variance
# -0.092 x 1 + -0.015 x 2 + -0.005 x 3 + 0.010 x 4 + 0.004 x 5 + 0.011 x 6
# 140 component: 0.05% of initial variance
# 0.025 x 1 + 0.001 x 2 + 0.013 x 3 + 0.001 x 4 + 0.012 x 5 + 0.009 x 6
# 141 component: 0.05% of initial variance
# 0.116 x 1 + -0.017 x 2 + 0.029 x 3 + -0.004 x 4 + 0.005 x 5 + -0.005 x 6
# 142 component: 0.05% of initial variance
# -0.124 x 1 + 0.012 x 2 + -0.037 x 3 + -0.008 x 4 + 0.008 x 5 + 0.005 x 6
# 143 component: 0.05% of initial variance
# -0.013 x 1 + -0.029 x 2 + -0.003 x 3 + -0.001 x 4 + -0.014 x 5 + 0.000 x 6
# 144 component: 0.05% of initial variance
# -0.147 x 1 + 0.014 x 2 + -0.036 x 3 + -0.006 x 4 + -0.006 x 5 + -0.016 x 6
# 145 component: 0.05% of initial variance
# -0.105 x 1 + 0.035 x 2 + -0.011 x 3 + 0.001 x 4 + 0.009 x 5 + 0.001 x 6
# 146 component: 0.05% of initial variance
# 0.207 x 1 + -0.064 x 2 + 0.036 x 3 + 0.006 x 4 + -0.004 x 5 + 0.019 x 6
# 147 component: 0.05% of initial variance
# -0.000 x 1 + 0.004 x 2 + -0.018 x 3 + -0.005 x 4 + 0.003 x 5 + 0.004 x 6
# 148 component: 0.04% of initial variance
# -0.173 x 1 + 0.024 x 2 + -0.062 x 3 + -0.006 x 4 + -0.002 x 5 + -0.002 x 6
# 149 component: 0.04% of initial variance
# 0.001 x 1 + 0.010 x 2 + -0.014 x 3 + 0.001 x 4 + -0.001 x 5 + 0.017 x 6
# 150 component: 0.04% of initial variance
# -0.037 x 1 + 0.009 x 2 + -0.000 x 3 + 0.012 x 4 + 0.001 x 5 + 0.010 x 6
# 151 component: 0.04% of initial variance
# 0.011 x 1 + 0.006 x 2 + -0.018 x 3 + -0.005 x 4 + -0.002 x 5 + 0.005 x 6
# 152 component: 0.04% of initial variance
# 0.063 x 1 + -0.011 x 2 + 0.008 x 3 + 0.008 x 4 + -0.003 x 5 + -0.015 x 6
# 153 component: 0.04% of initial variance
# 0.044 x 1 + -0.027 x 2 + 0.012 x 3 + -0.006 x 4 + 0.004 x 5 + 0.000 x 6
# 154 component: 0.04% of initial variance
# -0.018 x 1 + -0.002 x 2 + -0.022 x 3 + -0.003 x 4 + 0.004 x 5 + -0.014 x 6
# 155 component: 0.04% of initial variance
# -0.081 x 1 + 0.003 x 2 + -0.017 x 3 + 0.003 x 4 + -0.016 x 5 + 0.006 x 6
# 156 component: 0.04% of initial variance
# -0.082 x 1 + 0.012 x 2 + -0.018 x 3 + -0.016 x 4 + 0.008 x 5 + 0.008 x 6
# 157 component: 0.04% of initial variance
# -0.046 x 1 + -0.003 x 2 + -0.002 x 3 + -0.000 x 4 + 0.001 x 5 + 0.000 x 6
# 158 component: 0.04% of initial variance
# -0.010 x 1 + 0.008 x 2 + -0.017 x 3 + -0.001 x 4 + 0.003 x 5 + -0.009 x 6
# 159 component: 0.04% of initial variance
# -0.071 x 1 + 0.014 x 2 + -0.007 x 3 + -0.002 x 4 + 0.009 x 5 + 0.000 x 6
# 160 component: 0.04% of initial variance
# -0.024 x 1 + -0.012 x 2 + -0.022 x 3 + 0.004 x 4 + -0.003 x 5 + 0.001 x 6
# 161 component: 0.04% of initial variance
# 0.051 x 1 + -0.019 x 2 + 0.010 x 3 + 0.007 x 4 + -0.005 x 5 + 0.016 x 6
# 162 component: 0.04% of initial variance
# -0.071 x 1 + 0.015 x 2 + 0.023 x 3 + -0.012 x 4 + 0.005 x 5 + -0.007 x 6
# 163 component: 0.04% of initial variance
# 0.045 x 1 + 0.001 x 2 + -0.008 x 3 + 0.005 x 4 + -0.001 x 5 + 0.015 x 6
# 164 component: 0.04% of initial variance
# -0.005 x 1 + -0.002 x 2 + -0.016 x 3 + -0.002 x 4 + -0.008 x 5 + -0.016 x 6
# 165 component: 0.03% of initial variance
# 0.085 x 1 + -0.028 x 2 + -0.014 x 3 + -0.008 x 4 + -0.009 x 5 + -0.010 x 6
# 166 component: 0.03% of initial variance
# 0.040 x 1 + -0.026 x 2 + -0.005 x 3 + 0.000 x 4 + 0.009 x 5 + -0.000 x 6
# 167 component: 0.03% of initial variance
# 0.030 x 1 + 0.021 x 2 + -0.023 x 3 + -0.012 x 4 + 0.018 x 5 + 0.021 x 6
# 168 component: 0.03% of initial variance
# -0.028 x 1 + 0.020 x 2 + -0.012 x 3 + -0.013 x 4 + -0.021 x 5 + -0.016 x 6
# 169 component: 0.03% of initial variance
# 0.051 x 1 + -0.012 x 2 + -0.000 x 3 + 0.009 x 4 + 0.007 x 5 + -0.002 x 6
# 170 component: 0.03% of initial variance
# -0.013 x 1 + 0.005 x 2 + -0.004 x 3 + 0.028 x 4 + 0.015 x 5 + -0.005 x 6
# 171 component: 0.03% of initial variance
# -0.020 x 1 + 0.022 x 2 + 0.010 x 3 + 0.007 x 4 + -0.027 x 5 + -0.000 x 6
# 172 component: 0.03% of initial variance
# -0.015 x 1 + 0.013 x 2 + 0.041 x 3 + 0.010 x 4 + 0.002 x 5 + 0.017 x 6
# 173 component: 0.03% of initial variance
# -0.037 x 1 + -0.008 x 2 + 0.003 x 3 + 0.001 x 4 + -0.005 x 5 + -0.003 x 6
# 174 component: 0.03% of initial variance
# -0.002 x 1 + -0.012 x 2 + 0.013 x 3 + -0.017 x 4 + 0.001 x 5 + -0.023 x 6
# 175 component: 0.02% of initial variance
# 0.039 x 1 + -0.007 x 2 + 0.040 x 3 + -0.000 x 4 + -0.013 x 5 + -0.012 x 6
# 176 component: 0.02% of initial variance
# -0.012 x 1 + 0.018 x 2 + 0.037 x 3 + -0.004 x 4 + 0.000 x 5 + 0.016 x 6
# 177 component: 0.02% of initial variance
# -0.001 x 1 + -0.006 x 2 + -0.000 x 3 + 0.016 x 4 + 0.024 x 5 + 0.027 x 6
# 178 component: 0.02% of initial variance
# -0.023 x 1 + 0.001 x 2 + 0.040 x 3 + 0.003 x 4 + 0.024 x 5 + 0.029 x 6
# 179 component: 0.02% of initial variance
# 0.007 x 1 + 0.008 x 2 + 0.005 x 3 + -0.006 x 4 + 0.000 x 5 + -0.005 x 6
# 180 component: 0.02% of initial variance
# 0.040 x 1 + -0.016 x 2 + -0.052 x 3 + 0.015 x 4 + 0.008 x 5 + 0.012 x 6
# 181 component: 0.02% of initial variance
# -0.017 x 1 + -0.011 x 2 + -0.000 x 3 + -0.000 x 4 + 0.019 x 5 + -0.000 x 6
# 182 component: 0.02% of initial variance
# -0.021 x 1 + 0.032 x 2 + 0.046 x 3 + 0.008 x 4 + 0.008 x 5 + 0.022 x 6
# 183 component: 0.02% of initial variance
# -0.009 x 1 + -0.024 x 2 + -0.019 x 3 + 0.008 x 4 + -0.012 x 5 + -0.015 x 6
# 184 component: 0.02% of initial variance
# -0.007 x 1 + 0.017 x 2 + 0.034 x 3 + 0.020 x 4 + -0.009 x 5 + -0.027 x 6
# 185 component: 0.02% of initial variance
# 0.003 x 1 + 0.010 x 2 + 0.055 x 3 + -0.022 x 4 + -0.006 x 5 + -0.011 x 6
# 186 component: 0.02% of initial variance
# 0.055 x 1 + -0.009 x 2 + -0.031 x 3 + -0.008 x 4 + 0.011 x 5 + 0.031 x 6
# 187 component: 0.02% of initial variance
# 0.021 x 1 + 0.027 x 2 + 0.039 x 3 + 0.019 x 4 + 0.013 x 5 + 0.023 x 6
# 188 component: 0.02% of initial variance
# 0.047 x 1 + 0.047 x 2 + 0.151 x 3 + 0.015 x 4 + 0.003 x 5 + -0.013 x 6
# 189 component: 0.02% of initial variance
# 0.021 x 1 + 0.016 x 2 + -0.011 x 3 + 0.002 x 4 + 0.001 x 5 + -0.009 x 6
# 190 component: 0.02% of initial variance
# -0.021 x 1 + -0.026 x 2 + -0.105 x 3 + -0.015 x 4 + -0.001 x 5 + 0.032 x 6
# 191 component: 0.02% of initial variance
# 0.045 x 1 + 0.029 x 2 + 0.033 x 3 + 0.004 x 4 + 0.010 x 5 + 0.032 x 6
# 192 component: 0.02% of initial variance
# 0.003 x 1 + -0.014 x 2 + -0.026 x 3 + 0.014 x 4 + -0.012 x 5 + 0.040 x 6
# 193 component: 0.02% of initial variance
# 0.009 x 1 + -0.013 x 2 + -0.063 x 3 + 0.004 x 4 + -0.005 x 5 + -0.025 x 6
# 194 component: 0.02% of initial variance
# 0.072 x 1 + 0.011 x 2 + -0.055 x 3 + 0.021 x 4 + 0.007 x 5 + 0.027 x 6
# 195 component: 0.02% of initial variance
# 0.047 x 1 + 0.003 x 2 + 0.022 x 3 + -0.007 x 4 + 0.029 x 5 + -0.019 x 6
# 196 component: 0.02% of initial variance
# -0.006 x 1 + -0.023 x 2 + -0.017 x 3 + 0.027 x 4 + 0.020 x 5 + 0.048 x 6
# 197 component: 0.01% of initial variance
# 0.028 x 1 + -0.009 x 2 + -0.013 x 3 + -0.008 x 4 + -0.002 x 5 + -0.019 x 6
# 198 component: 0.01% of initial variance
# 0.018 x 1 + 0.051 x 2 + -0.068 x 3 + -0.007 x 4 + -0.017 x 5 + 0.019 x 6
# 199 component: 0.01% of initial variance
# -0.059 x 1 + 0.047 x 2 + 0.064 x 3 + -0.008 x 4 + -0.038 x 5 + 0.028 x 6
# 200 component: 0.01% of initial variance
# 0.025 x 1 + 0.077 x 2 + -0.062 x 3 + 0.013 x 4 + -0.028 x 5 + 0.020 x 6
# 201 component: 0.01% of initial variance
# -0.090 x 1 + 0.034 x 2 + 0.009 x 3 + -0.013 x 4 + -0.032 x 5 + 0.027 x 6
# 202 component: 0.01% of initial variance
# 0.072 x 1 + -0.034 x 2 + -0.021 x 3 + -0.014 x 4 + -0.024 x 5 + 0.018 x 6
# 203 component: 0.01% of initial variance
# 0.009 x 1 + 0.056 x 2 + 0.001 x 3 + -0.016 x 4 + -0.017 x 5 + 0.014 x 6
# 204 component: 0.01% of initial variance
# -0.037 x 1 + 0.024 x 2 + 0.097 x 3 + 0.029 x 4 + -0.025 x 5 + -0.024 x 6
# 205 component: 0.01% of initial variance
# 0.003 x 1 + 0.070 x 2 + 0.000 x 3 + 0.045 x 4 + -0.013 x 5 + -0.014 x 6
# 206 component: 0.01% of initial variance
# 0.004 x 1 + -0.002 x 2 + 0.039 x 3 + -0.012 x 4 + 0.020 x 5 + -0.019 x 6
# 207 component: 0.01% of initial variance
# 0.043 x 1 + 0.074 x 2 + 0.073 x 3 + -0.018 x 4 + 0.002 x 5 + -0.002 x 6
# 208 component: 0.01% of initial variance
# -0.003 x 1 + -0.034 x 2 + 0.012 x 3 + 0.007 x 4 + 0.047 x 5 + 0.001 x 6
# 209 component: 0.01% of initial variance
# -0.042 x 1 + 0.054 x 2 + -0.039 x 3 + 0.017 x 4 + -0.000 x 5 + -0.029 x 6
# 210 component: 0.01% of initial variance
# 0.041 x 1 + -0.044 x 2 + -0.068 x 3 + 0.024 x 4 + -0.005 x 5 + -0.006 x 6
# 211 component: 0.01% of initial variance
# 0.069 x 1 + -0.056 x 2 + 0.024 x 3 + -0.020 x 4 + -0.013 x 5 + -0.006 x 6
# 212 component: 0.01% of initial variance
# 0.081 x 1 + 0.093 x 2 + -0.021 x 3 + 0.003 x 4 + 0.023 x 5 + -0.004 x 6
# 213 component: 0.01% of initial variance
# -0.015 x 1 + 0.042 x 2 + 0.010 x 3 + 0.010 x 4 + -0.001 x 5 + 0.027 x 6
# 214 component: 0.01% of initial variance
# 0.030 x 1 + -0.079 x 2 + 0.018 x 3 + 0.015 x 4 + -0.003 x 5 + 0.008 x 6
# 215 component: 0.01% of initial variance
# -0.013 x 1 + -0.007 x 2 + 0.002 x 3 + -0.003 x 4 + -0.011 x 5 + -0.014 x 6
# 216 component: 0.01% of initial variance
# -0.001 x 1 + 0.044 x 2 + -0.013 x 3 + -0.006 x 4 + -0.000 x 5 + -0.006 x 6
# 217 component: 0.01% of initial variance
# 0.015 x 1 + -0.006 x 2 + 0.005 x 3 + 0.000 x 4 + -0.006 x 5 + -0.004 x 6
# 218 component: 0.01% of initial variance
# -0.098 x 1 + 0.040 x 2 + 0.010 x 3 + -0.002 x 4 + 0.010 x 5 + 0.004 x 6
# 219 component: 0.01% of initial variance
# 0.062 x 1 + -0.011 x 2 + -0.007 x 3 + 0.016 x 4 + 0.001 x 5 + -0.006 x 6
# 220 component: 0.01% of initial variance
# -0.022 x 1 + -0.037 x 2 + 0.008 x 3 + -0.014 x 4 + 0.026 x 5 + -0.007 x 6
# 221 component: 0.01% of initial variance
# -0.026 x 1 + -0.023 x 2 + -0.058 x 3 + -0.001 x 4 + 0.035 x 5 + -0.013 x 6
# 222 component: 0.01% of initial variance
# -0.019 x 1 + 0.022 x 2 + -0.064 x 3 + -0.033 x 4 + 0.005 x 5 + 0.020 x 6
# 223 component: 0.01% of initial variance
# -0.001 x 1 + 0.024 x 2 + -0.041 x 3 + 0.022 x 4 + -0.019 x 5 + -0.004 x 6
# 224 component: 0.01% of initial variance
# -0.007 x 1 + 0.002 x 2 + 0.007 x 3 + -0.002 x 4 + 0.026 x 5 + -0.003 x 6
# 225 component: 0.01% of initial variance
# 0.017 x 1 + -0.002 x 2 + -0.031 x 3 + 0.008 x 4 + -0.034 x 5 + -0.019 x 6
# 226 component: 0.01% of initial variance
# 0.007 x 1 + -0.018 x 2 + 0.010 x 3 + 0.002 x 4 + 0.013 x 5 + 0.014 x 6
# 227 component: 0.01% of initial variance
# -0.003 x 1 + 0.018 x 2 + 0.077 x 3 + -0.031 x 4 + 0.008 x 5 + 0.004 x 6
# 228 component: 0.01% of initial variance
# -0.058 x 1 + -0.005 x 2 + 0.009 x 3 + 0.028 x 4 + -0.031 x 5 + -0.025 x 6
# 229 component: 0.01% of initial variance
# 0.010 x 1 + 0.006 x 2 + -0.017 x 3 + 0.033 x 4 + 0.012 x 5 + -0.002 x 6
# 230 component: 0.01% of initial variance
# -0.009 x 1 + 0.036 x 2 + -0.012 x 3 + 0.009 x 4 + 0.007 x 5 + 0.014 x 6
# 231 component: 0.01% of initial variance
# 0.023 x 1 + -0.028 x 2 + -0.043 x 3 + 0.007 x 4 + -0.020 x 5 + -0.006 x 6
# 232 component: 0.01% of initial variance
# 0.003 x 1 + 0.029 x 2 + -0.000 x 3 + -0.017 x 4 + 0.011 x 5 + 0.008 x 6
# 233 component: 0.01% of initial variance
# 0.006 x 1 + 0.023 x 2 + -0.018 x 3 + 0.014 x 4 + 0.027 x 5 + -0.012 x 6
# 234 component: 0.01% of initial variance
# 0.011 x 1 + -0.019 x 2 + -0.004 x 3 + -0.014 x 4 + 0.004 x 5 + 0.002 x 6
# 235 component: 0.01% of initial variance
# 0.013 x 1 + -0.006 x 2 + 0.030 x 3 + 0.005 x 4 + -0.004 x 5 + 0.017 x 6
# 236 component: 0.01% of initial variance
# 0.026 x 1 + 0.016 x 2 + 0.028 x 3 + 0.031 x 4 + -0.009 x 5 + -0.008 x 6
# 237 component: 0.01% of initial variance
# -0.006 x 1 + -0.015 x 2 + -0.033 x 3 + -0.025 x 4 + -0.008 x 5 + -0.008 x 6
# 238 component: 0.01% of initial variance
# 0.015 x 1 + 0.013 x 2 + 0.017 x 3 + -0.018 x 4 + -0.017 x 5 + 0.025 x 6
# 239 component: 0.01% of initial variance
# -0.006 x 1 + 0.003 x 2 + -0.001 x 3 + -0.040 x 4 + 0.003 x 5 + -0.004 x 6
# 240 component: 0.01% of initial variance
# -0.024 x 1 + -0.020 x 2 + -0.010 x 3 + -0.009 x 4 + 0.008 x 5 + -0.021 x 6
# 241 component: 0.01% of initial variance
# 0.001 x 1 + -0.010 x 2 + 0.010 x 3 + 0.011 x 4 + -0.006 x 5 + 0.016 x 6
# 242 component: 0.01% of initial variance
# 0.015 x 1 + -0.001 x 2 + -0.006 x 3 + 0.014 x 4 + 0.007 x 5 + 0.007 x 6
# 243 component: 0.01% of initial variance
# 0.008 x 1 + 0.005 x 2 + 0.014 x 3 + 0.008 x 4 + 0.014 x 5 + 0.005 x 6
# 244 component: 0.01% of initial variance
# 0.039 x 1 + -0.007 x 2 + 0.012 x 3 + -0.019 x 4 + -0.003 x 5 + 0.014 x 6
# 245 component: 0.01% of initial variance
# -0.019 x 1 + 0.023 x 2 + 0.014 x 3 + -0.011 x 4 + -0.008 x 5 + 0.011 x 6
# 246 component: 0.01% of initial variance
# -0.018 x 1 + 0.018 x 2 + -0.023 x 3 + -0.038 x 4 + -0.016 x 5 + -0.010 x 6
# 247 component: 0.01% of initial variance
# 0.006 x 1 + 0.016 x 2 + -0.002 x 3 + -0.011 x 4 + 0.008 x 5 + 0.005 x 6
# 248 component: 0.01% of initial variance
# -0.024 x 1 + 0.005 x 2 + -0.034 x 3 + -0.007 x 4 + -0.022 x 5 + -0.011 x 6
# 249 component: 0.01% of initial variance
# 0.037 x 1 + -0.025 x 2 + -0.022 x 3 + -0.010 x 4 + -0.031 x 5 + 0.002 x 6
# 250 component: 0.01% of initial variance
# 0.010 x 1 + 0.007 x 2 + -0.016 x 3 + 0.013 x 4 + 0.011 x 5 + -0.020 x 6
# 251 component: 0.0% of initial variance
# 0.022 x 1 + 0.003 x 2 + 0.008 x 3 + -0.005 x 4 + 0.023 x 5 + -0.005 x 6
# 252 component: 0.0% of initial variance
# -0.029 x 1 + 0.005 x 2 + -0.012 x 3 + -0.028 x 4 + -0.011 x 5 + 0.013 x 6
# 253 component: 0.0% of initial variance
# -0.017 x 1 + 0.020 x 2 + 0.003 x 3 + -0.009 x 4 + 0.002 x 5 + -0.007 x 6
# 254 component: 0.0% of initial variance
# -0.015 x 1 + 0.029 x 2 + -0.001 x 3 + -0.012 x 4 + 0.019 x 5 + 0.012 x 6
# 255 component: 0.0% of initial variance
# 0.027 x 1 + -0.001 x 2 + -0.002 x 3 + 0.005 x 4 + -0.014 x 5 + -0.018 x 6
# 256 component: 0.0% of initial variance
# -0.025 x 1 + 0.005 x 2 + -0.003 x 3 + 0.028 x 4 + 0.012 x 5 + -0.008 x 6
# 257 component: 0.0% of initial variance
# -0.022 x 1 + -0.005 x 2 + -0.018 x 3 + -0.027 x 4 + 0.023 x 5 + -0.001 x 6
# 258 component: 0.0% of initial variance
# 0.040 x 1 + 0.018 x 2 + -0.003 x 3 + -0.021 x 4 + 0.022 x 5 + -0.031 x 6
# 259 component: 0.0% of initial variance
# -0.034 x 1 + 0.009 x 2 + 0.002 x 3 + -0.030 x 4 + 0.016 x 5 + 0.007 x 6
# 260 component: 0.0% of initial variance
# 0.000 x 1 + -0.022 x 2 + -0.006 x 3 + -0.020 x 4 + -0.026 x 5 + 0.012 x 6
# 261 component: 0.0% of initial variance
# -0.022 x 1 + 0.004 x 2 + -0.014 x 3 + 0.002 x 4 + 0.014 x 5 + -0.026 x 6
# 262 component: 0.0% of initial variance
# -0.023 x 1 + -0.004 x 2 + -0.012 x 3 + 0.006 x 4 + -0.019 x 5 + -0.020 x 6
# 263 component: 0.0% of initial variance
# 0.018 x 1 + 0.004 x 2 + 0.002 x 3 + -0.002 x 4 + 0.002 x 5 + -0.031 x 6
# 264 component: 0.0% of initial variance
# -0.011 x 1 + -0.006 x 2 + 0.005 x 3 + 0.014 x 4 + 0.012 x 5 + 0.012 x 6
# 265 component: 0.0% of initial variance
# 0.030 x 1 + -0.008 x 2 + 0.006 x 3 + -0.014 x 4 + -0.009 x 5 + 0.018 x 6
# 266 component: 0.0% of initial variance
# -0.003 x 1 + 0.010 x 2 + -0.007 x 3 + 0.010 x 4 + 0.023 x 5 + -0.031 x 6
# 267 component: 0.0% of initial variance
# -0.012 x 1 + 0.005 x 2 + 0.001 x 3 + -0.013 x 4 + -0.011 x 5 + 0.021 x 6
# 268 component: 0.0% of initial variance
# 0.001 x 1 + -0.001 x 2 + 0.006 x 3 + -0.017 x 4 + 0.015 x 5 + 0.038 x 6
# 269 component: 0.0% of initial variance
# -0.016 x 1 + 0.000 x 2 + -0.002 x 3 + 0.012 x 4 + -0.005 x 5 + -0.008 x 6
# 270 component: 0.0% of initial variance
# -0.018 x 1 + -0.004 x 2 + -0.008 x 3 + 0.005 x 4 + 0.014 x 5 + -0.018 x 6
# 271 component: 0.0% of initial variance
# 0.017 x 1 + -0.006 x 2 + 0.003 x 3 + 0.004 x 4 + -0.015 x 5 + -0.026 x 6
# 272 component: 0.0% of initial variance
# -0.020 x 1 + -0.001 x 2 + -0.003 x 3 + 0.016 x 4 + -0.012 x 5 + 0.003 x 6
# 273 component: 0.0% of initial variance
# 0.016 x 1 + 0.008 x 2 + -0.015 x 3 + -0.019 x 4 + 0.001 x 5 + -0.014 x 6
# 274 component: 0.0% of initial variance
# 0.010 x 1 + -0.009 x 2 + -0.011 x 3 + -0.002 x 4 + 0.010 x 5 + -0.005 x 6
# 275 component: 0.0% of initial variance
# 0.001 x 1 + 0.019 x 2 + -0.023 x 3 + -0.001 x 4 + 0.032 x 5 + -0.003 x 6
# 276 component: 0.0% of initial variance
# 0.023 x 1 + 0.006 x 2 + -0.005 x 3 + -0.035 x 4 + 0.010 x 5 + -0.028 x 6
# 277 component: 0.0% of initial variance
# 0.014 x 1 + -0.001 x 2 + -0.018 x 3 + -0.014 x 4 + 0.009 x 5 + -0.033 x 6
# 278 component: 0.0% of initial variance
# -0.017 x 1 + 0.014 x 2 + 0.008 x 3 + 0.003 x 4 + 0.003 x 5 + 0.010 x 6
# 279 component: 0.0% of initial variance
# 0.014 x 1 + -0.001 x 2 + 0.006 x 3 + -0.002 x 4 + 0.000 x 5 + -0.012 x 6
# 280 component: 0.0% of initial variance
# -0.008 x 1 + 0.003 x 2 + 0.008 x 3 + -0.009 x 4 + 0.021 x 5 + 0.012 x 6
# 281 component: 0.0% of initial variance
# 0.017 x 1 + 0.003 x 2 + -0.012 x 3 + -0.012 x 4 + 0.012 x 5 + -0.011 x 6
# 282 component: 0.0% of initial variance
# -0.015 x 1 + -0.002 x 2 + -0.002 x 3 + -0.013 x 4 + 0.010 x 5 + -0.001 x 6
# 283 component: 0.0% of initial variance
# -0.005 x 1 + -0.012 x 2 + -0.008 x 3 + -0.002 x 4 + -0.039 x 5 + 0.009 x 6
# 284 component: 0.0% of initial variance
# 0.004 x 1 + -0.003 x 2 + -0.006 x 3 + 0.009 x 4 + 0.024 x 5 + -0.035 x 6
# 285 component: 0.0% of initial variance
# 0.011 x 1 + 0.007 x 2 + -0.010 x 3 + -0.034 x 4 + 0.030 x 5 + -0.020 x 6
# 286 component: 0.0% of initial variance
# 0.002 x 1 + 0.005 x 2 + -0.007 x 3 + -0.013 x 4 + 0.007 x 5 + -0.036 x 6
# 287 component: 0.0% of initial variance
# 0.008 x 1 + -0.003 x 2 + -0.001 x 3 + -0.015 x 4 + -0.011 x 5 + -0.000 x 6
# 288 component: 0.0% of initial variance
# 0.010 x 1 + 0.008 x 2 + 0.001 x 3 + 0.003 x 4 + 0.000 x 5 + -0.009 x 6
# 289 component: 0.0% of initial variance
# -0.004 x 1 + -0.002 x 2 + 0.007 x 3 + 0.010 x 4 + 0.008 x 5 + 0.013 x 6
# 290 component: 0.0% of initial variance
# -0.004 x 1 + 0.008 x 2 + 0.004 x 3 + -0.003 x 4 + 0.011 x 5 + -0.006 x 6
# 291 component: 0.0% of initial variance
# -0.001 x 1 + -0.001 x 2 + 0.002 x 3 + 0.019 x 4 + -0.011 x 5 + -0.008 x 6
# 292 component: 0.0% of initial variance
# -0.004 x 1 + 0.004 x 2 + -0.011 x 3 + 0.036 x 4 + 0.021 x 5 + -0.004 x 6
# 293 component: 0.0% of initial variance
# 0.016 x 1 + -0.005 x 2 + -0.010 x 3 + -0.001 x 4 + 0.015 x 5 + 0.003 x 6
# 294 component: 0.0% of initial variance
# 0.001 x 1 + 0.012 x 2 + 0.009 x 3 + 0.004 x 4 + 0.011 x 5 + -0.014 x 6
# 295 component: 0.0% of initial variance
# 0.002 x 1 + 0.004 x 2 + -0.004 x 3 + -0.026 x 4 + 0.006 x 5 + -0.025 x 6
# 296 component: 0.0% of initial variance
# -0.006 x 1 + -0.006 x 2 + 0.003 x 3 + -0.012 x 4 + -0.013 x 5 + -0.032 x 6
# 297 component: 0.0% of initial variance
# -0.004 x 1 + 0.001 x 2 + -0.005 x 3 + 0.008 x 4 + 0.029 x 5 + 0.003 x 6
# 298 component: 0.0% of initial variance
# -0.003 x 1 + 0.017 x 2 + 0.012 x 3 + -0.027 x 4 + 0.021 x 5 + -0.001 x 6
# 299 component: 0.0% of initial variance
# -0.020 x 1 + 0.003 x 2 + 0.006 x 3 + -0.006 x 4 + -0.020 x 5 + 0.035 x 6
# 300 component: 0.0% of initial variance
# -0.008 x 1 + -0.002 x 2 + -0.016 x 3 + 0.011 x 4 + 0.036 x 5 + -0.005 x 6
# 301 component: 0.0% of initial variance
# -0.008 x 1 + 0.001 x 2 + 0.006 x 3 + 0.002 x 4 + -0.032 x 5 + 0.008 x 6
# 302 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + -0.006 x 3 + -0.025 x 4 + -0.002 x 5 + -0.005 x 6
# 303 component: 0.0% of initial variance
# 0.007 x 1 + -0.007 x 2 + -0.003 x 3 + -0.017 x 4 + 0.008 x 5 + 0.004 x 6
# 304 component: 0.0% of initial variance
# 0.011 x 1 + 0.000 x 2 + -0.003 x 3 + -0.027 x 4 + -0.022 x 5 + -0.036 x 6
# 305 component: 0.0% of initial variance
# 0.002 x 1 + 0.004 x 2 + -0.009 x 3 + -0.002 x 4 + 0.003 x 5 + -0.037 x 6
# 306 component: 0.0% of initial variance
# 0.008 x 1 + -0.003 x 2 + -0.006 x 3 + -0.008 x 4 + 0.016 x 5 + -0.026 x 6
# 307 component: 0.0% of initial variance
# 0.002 x 1 + -0.002 x 2 + 0.006 x 3 + 0.016 x 4 + 0.022 x 5 + 0.037 x 6
# 308 component: 0.0% of initial variance
# 0.008 x 1 + -0.005 x 2 + 0.001 x 3 + 0.005 x 4 + 0.000 x 5 + -0.043 x 6
# 309 component: 0.0% of initial variance
# 0.002 x 1 + -0.004 x 2 + -0.002 x 3 + 0.006 x 4 + -0.008 x 5 + 0.026 x 6
# 310 component: 0.0% of initial variance
# 0.014 x 1 + -0.000 x 2 + -0.011 x 3 + -0.025 x 4 + -0.021 x 5 + -0.018 x 6
# 311 component: 0.0% of initial variance
# -0.002 x 1 + -0.001 x 2 + 0.004 x 3 + 0.011 x 4 + -0.005 x 5 + 0.035 x 6
# 312 component: 0.0% of initial variance
# 0.002 x 1 + 0.001 x 2 + -0.002 x 3 + -0.023 x 4 + 0.001 x 5 + -0.015 x 6
# 313 component: 0.0% of initial variance
# -0.005 x 1 + -0.004 x 2 + -0.009 x 3 + 0.000 x 4 + 0.004 x 5 + 0.004 x 6
# 314 component: 0.0% of initial variance
# 0.003 x 1 + -0.001 x 2 + -0.001 x 3 + -0.006 x 4 + -0.015 x 5 + -0.007 x 6
# 315 component: 0.0% of initial variance
# 0.009 x 1 + 0.000 x 2 + -0.007 x 3 + -0.036 x 4 + -0.025 x 5 + -0.016 x 6
# 316 component: 0.0% of initial variance
# -0.007 x 1 + 0.002 x 2 + -0.000 x 3 + -0.005 x 4 + -0.007 x 5 + -0.051 x 6
# 317 component: 0.0% of initial variance
# 0.007 x 1 + 0.002 x 2 + 0.002 x 3 + 0.012 x 4 + 0.031 x 5 + -0.004 x 6
# 318 component: 0.0% of initial variance
# -0.008 x 1 + 0.006 x 2 + -0.000 x 3 + 0.003 x 4 + -0.018 x 5 + 0.013 x 6
# 319 component: 0.0% of initial variance
# 0.009 x 1 + -0.006 x 2 + 0.003 x 3 + -0.041 x 4 + 0.002 x 5 + 0.018 x 6
# 320 component: 0.0% of initial variance
# -0.006 x 1 + -0.002 x 2 + 0.002 x 3 + -0.000 x 4 + 0.016 x 5 + 0.014 x 6
# 321 component: 0.0% of initial variance
# -0.006 x 1 + 0.007 x 2 + 0.007 x 3 + 0.038 x 4 + 0.022 x 5 + 0.056 x 6
# 322 component: 0.0% of initial variance
# 0.008 x 1 + -0.001 x 2 + -0.001 x 3 + -0.038 x 4 + 0.001 x 5 + -0.017 x 6
# 323 component: 0.0% of initial variance
# -0.003 x 1 + 0.005 x 2 + 0.005 x 3 + 0.023 x 4 + -0.010 x 5 + 0.023 x 6
# 324 component: 0.0% of initial variance
# 0.010 x 1 + -0.004 x 2 + -0.004 x 3 + 0.005 x 4 + 0.020 x 5 + 0.069 x 6
# 325 component: 0.0% of initial variance
# -0.002 x 1 + 0.004 x 2 + -0.004 x 3 + -0.018 x 4 + 0.018 x 5 + 0.048 x 6
# 326 component: 0.0% of initial variance
# 0.010 x 1 + -0.012 x 2 + -0.005 x 3 + -0.045 x 4 + -0.004 x 5 + 0.029 x 6
# 327 component: 0.0% of initial variance
# -0.001 x 1 + 0.000 x 2 + 0.000 x 3 + -0.005 x 4 + 0.008 x 5 + 0.079 x 6
# 328 component: 0.0% of initial variance
# 0.003 x 1 + -0.002 x 2 + 0.005 x 3 + -0.036 x 4 + 0.015 x 5 + -0.020 x 6
# 329 component: 0.0% of initial variance
# 0.014 x 1 + -0.002 x 2 + 0.005 x 3 + -0.008 x 4 + 0.005 x 5 + 0.034 x 6
# 330 component: 0.0% of initial variance
# -0.007 x 1 + 0.003 x 2 + 0.000 x 3 + 0.013 x 4 + -0.032 x 5 + -0.007 x 6
# 331 component: 0.0% of initial variance
# 0.016 x 1 + -0.000 x 2 + -0.003 x 3 + -0.026 x 4 + -0.001 x 5 + -0.018 x 6
# 332 component: 0.0% of initial variance
# -0.004 x 1 + -0.001 x 2 + -0.002 x 3 + 0.004 x 4 + -0.005 x 5 + -0.054 x 6
# 333 component: 0.0% of initial variance
# -0.001 x 1 + 0.000 x 2 + 0.002 x 3 + 0.009 x 4 + -0.026 x 5 + -0.033 x 6
# 334 component: 0.0% of initial variance
# -0.002 x 1 + 0.006 x 2 + 0.000 x 3 + -0.024 x 4 + 0.061 x 5 + 0.057 x 6
# 335 component: 0.0% of initial variance
# -0.005 x 1 + -0.006 x 2 + 0.001 x 3 + -0.018 x 4 + 0.010 x 5 + 0.004 x 6
# 336 component: 0.0% of initial variance
# 0.004 x 1 + -0.001 x 2 + -0.002 x 3 + 0.035 x 4 + 0.024 x 5 + 0.003 x 6
# 337 component: 0.0% of initial variance
# -0.013 x 1 + 0.003 x 2 + 0.003 x 3 + -0.020 x 4 + -0.016 x 5 + -0.051 x 6
# 338 component: 0.0% of initial variance
# -0.010 x 1 + 0.004 x 2 + -0.004 x 3 + -0.007 x 4 + -0.027 x 5 + -0.030 x 6
# 339 component: 0.0% of initial variance
# -0.008 x 1 + -0.002 x 2 + 0.001 x 3 + 0.012 x 4 + -0.010 x 5 + 0.034 x 6
# 340 component: 0.0% of initial variance
# -0.005 x 1 + 0.001 x 2 + -0.001 x 3 + -0.046 x 4 + -0.022 x 5 + -0.041 x 6
# 341 component: 0.0% of initial variance
# -0.005 x 1 + 0.000 x 2 + 0.000 x 3 + -0.012 x 4 + 0.063 x 5 + -0.061 x 6
# 342 component: 0.0% of initial variance
# -0.001 x 1 + -0.007 x 2 + 0.001 x 3 + -0.000 x 4 + -0.055 x 5 + -0.018 x 6
# 343 component: 0.0% of initial variance
# -0.004 x 1 + -0.001 x 2 + -0.004 x 3 + -0.040 x 4 + 0.102 x 5 + -0.011 x 6
# 344 component: 0.0% of initial variance
# -0.001 x 1 + -0.001 x 2 + -0.003 x 3 + -0.035 x 4 + -0.072 x 5 + 0.109 x 6
# 345 component: 0.0% of initial variance
# 0.001 x 1 + 0.001 x 2 + 0.001 x 3 + 0.037 x 4 + -0.002 x 5 + -0.039 x 6
# 346 component: 0.0% of initial variance
# 0.004 x 1 + 0.001 x 2 + 0.003 x 3 + 0.016 x 4 + -0.015 x 5 + 0.025 x 6
# 347 component: 0.0% of initial variance
# -0.002 x 1 + 0.002 x 2 + 0.002 x 3 + -0.031 x 4 + -0.031 x 5 + 0.015 x 6
# 348 component: 0.0% of initial variance
# -0.006 x 1 + -0.002 x 2 + 0.002 x 3 + -0.030 x 4 + 0.019 x 5 + 0.041 x 6
# 349 component: 0.0% of initial variance
# 0.002 x 1 + 0.000 x 2 + -0.001 x 3 + 0.066 x 4 + -0.076 x 5 + -0.049 x 6
# 350 component: 0.0% of initial variance
# 0.003 x 1 + -0.001 x 2 + 0.003 x 3 + -0.027 x 4 + 0.017 x 5 + 0.082 x 6
# 351 component: 0.0% of initial variance
# -0.000 x 1 + -0.004 x 2 + 0.001 x 3 + 0.038 x 4 + -0.005 x 5 + -0.010 x 6
# 352 component: 0.0% of initial variance
# -0.007 x 1 + 0.003 x 2 + 0.002 x 3 + 0.025 x 4 + 0.003 x 5 + 0.008 x 6
# 353 component: 0.0% of initial variance
# -0.000 x 1 + -0.002 x 2 + 0.000 x 3 + -0.054 x 4 + 0.005 x 5 + 0.051 x 6
# 354 component: 0.0% of initial variance
# -0.004 x 1 + 0.001 x 2 + -0.002 x 3 + 0.018 x 4 + 0.004 x 5 + -0.014 x 6
# 355 component: 0.0% of initial variance
# 0.000 x 1 + -0.001 x 2 + -0.003 x 3 + 0.022 x 4 + 0.006 x 5 + -0.047 x 6
# 356 component: 0.0% of initial variance
# -0.002 x 1 + 0.002 x 2 + -0.000 x 3 + 0.004 x 4 + -0.043 x 5 + 0.007 x 6
# 357 component: 0.0% of initial variance
# 0.000 x 1 + 0.002 x 2 + 0.003 x 3 + 0.001 x 4 + -0.014 x 5 + 0.024 x 6
# 358 component: 0.0% of initial variance
# -0.004 x 1 + 0.000 x 2 + 0.000 x 3 + 0.034 x 4 + 0.095 x 5 + -0.088 x 6
# 359 component: 0.0% of initial variance
# -0.003 x 1 + 0.001 x 2 + 0.002 x 3 + 0.013 x 4 + 0.095 x 5 + -0.035 x 6
# 360 component: 0.0% of initial variance
# 0.001 x 1 + 0.002 x 2 + -0.004 x 3 + -0.027 x 4 + 0.017 x 5 + 0.007 x 6
# 361 component: 0.0% of initial variance
# -0.002 x 1 + -0.001 x 2 + 0.000 x 3 + -0.013 x 4 + -0.023 x 5 + -0.032 x 6
# 362 component: 0.0% of initial variance
# -0.002 x 1 + 0.002 x 2 + -0.000 x 3 + -0.046 x 4 + -0.002 x 5 + 0.029 x 6
# 363 component: 0.0% of initial variance
# 0.003 x 1 + -0.002 x 2 + -0.001 x 3 + 0.046 x 4 + 0.005 x 5 + 0.062 x 6
# 364 component: 0.0% of initial variance
# 0.001 x 1 + 0.001 x 2 + -0.002 x 3 + -0.037 x 4 + 0.083 x 5 + 0.016 x 6
# 365 component: 0.0% of initial variance
# -0.003 x 1 + -0.003 x 2 + 0.002 x 3 + 0.042 x 4 + -0.032 x 5 + -0.040 x 6
# 366 component: 0.0% of initial variance
# -0.004 x 1 + 0.002 x 2 + 0.003 x 3 + 0.063 x 4 + -0.105 x 5 + 0.032 x 6
# 367 component: 0.0% of initial variance
# -0.001 x 1 + 0.002 x 2 + -0.002 x 3 + 0.000 x 4 + -0.055 x 5 + -0.001 x 6
# 368 component: 0.0% of initial variance
# -0.001 x 1 + 0.001 x 2 + -0.002 x 3 + 0.021 x 4 + 0.037 x 5 + -0.012 x 6
# 369 component: 0.0% of initial variance
# -0.001 x 1 + 0.002 x 2 + -0.001 x 3 + -0.010 x 4 + -0.027 x 5 + -0.024 x 6
# 370 component: 0.0% of initial variance
# 0.001 x 1 + 0.004 x 2 + -0.002 x 3 + 0.049 x 4 + -0.002 x 5 + 0.008 x 6
# 371 component: 0.0% of initial variance
# -0.003 x 1 + 0.002 x 2 + -0.001 x 3 + -0.001 x 4 + -0.018 x 5 + 0.020 x 6
# 372 component: 0.0% of initial variance
# 0.004 x 1 + 0.002 x 2 + -0.004 x 3 + 0.021 x 4 + 0.106 x 5 + -0.000 x 6
# 373 component: 0.0% of initial variance
# 0.002 x 1 + -0.001 x 2 + 0.001 x 3 + 0.058 x 4 + -0.009 x 5 + 0.030 x 6
# 374 component: 0.0% of initial variance
# -0.001 x 1 + -0.002 x 2 + 0.001 x 3 + 0.030 x 4 + -0.020 x 5 + -0.013 x 6
# 375 component: 0.0% of initial variance
# -0.003 x 1 + -0.001 x 2 + 0.003 x 3 + -0.006 x 4 + -0.072 x 5 + 0.009 x 6
# 376 component: 0.0% of initial variance
# -0.000 x 1 + -0.003 x 2 + -0.001 x 3 + 0.002 x 4 + 0.020 x 5 + 0.025 x 6
# 377 component: 0.0% of initial variance
# 0.001 x 1 + 0.001 x 2 + 0.000 x 3 + 0.005 x 4 + -0.013 x 5 + -0.005 x 6
# 378 component: 0.0% of initial variance
# 0.001 x 1 + 0.002 x 2 + -0.000 x 3 + 0.009 x 4 + -0.029 x 5 + 0.008 x 6
# 379 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + 0.001 x 3 + -0.019 x 4 + 0.031 x 5 + 0.021 x 6
# 380 component: 0.0% of initial variance
# -0.003 x 1 + -0.003 x 2 + 0.003 x 3 + 0.009 x 4 + -0.024 x 5 + 0.002 x 6
# 381 component: 0.0% of initial variance
# 0.005 x 1 + -0.004 x 2 + 0.001 x 3 + 0.009 x 4 + 0.021 x 5 + 0.033 x 6
# 382 component: 0.0% of initial variance
# -0.001 x 1 + -0.001 x 2 + 0.002 x 3 + 0.002 x 4 + -0.039 x 5 + 0.023 x 6
# 383 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + 0.001 x 3 + -0.000 x 4 + -0.000 x 5 + -0.006 x 6
# 384 component: 0.0% of initial variance
# -0.001 x 1 + 0.001 x 2 + 0.001 x 3 + 0.062 x 4 + -0.025 x 5 + -0.011 x 6
# 385 component: 0.0% of initial variance
# 0.001 x 1 + 0.001 x 2 + -0.001 x 3 + 0.014 x 4 + 0.055 x 5 + 0.033 x 6
# 386 component: 0.0% of initial variance
# -0.002 x 1 + 0.001 x 2 + 0.001 x 3 + -0.003 x 4 + -0.022 x 5 + -0.009 x 6
# 387 component: 0.0% of initial variance
# -0.003 x 1 + 0.002 x 2 + -0.001 x 3 + -0.005 x 4 + 0.003 x 5 + -0.011 x 6
# 388 component: 0.0% of initial variance
# -0.001 x 1 + 0.003 x 2 + -0.001 x 3 + 0.103 x 4 + 0.055 x 5 + 0.007 x 6
# 389 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + -0.001 x 3 + 0.023 x 4 + 0.047 x 5 + -0.018 x 6
# 390 component: 0.0% of initial variance
# -0.000 x 1 + -0.000 x 2 + -0.000 x 3 + 0.026 x 4 + -0.011 x 5 + 0.004 x 6
# 391 component: 0.0% of initial variance
# -0.003 x 1 + 0.001 x 2 + 0.000 x 3 + 0.080 x 4 + 0.004 x 5 + 0.003 x 6
# 392 component: 0.0% of initial variance
# 0.001 x 1 + -0.001 x 2 + -0.001 x 3 + 0.042 x 4 + -0.020 x 5 + -0.155 x 6
# 393 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + -0.001 x 3 + 0.038 x 4 + 0.030 x 5 + 0.142 x 6
# 394 component: 0.0% of initial variance
# -0.001 x 1 + -0.000 x 2 + 0.001 x 3 + 0.013 x 4 + -0.060 x 5 + -0.104 x 6
# 395 component: 0.0% of initial variance
# -0.002 x 1 + 0.000 x 2 + -0.002 x 3 + -0.043 x 4 + 0.026 x 5 + -0.066 x 6
# 396 component: 0.0% of initial variance
# 0.002 x 1 + -0.000 x 2 + -0.000 x 3 + 0.035 x 4 + -0.024 x 5 + 0.032 x 6
# 397 component: 0.0% of initial variance
# 0.001 x 1 + 0.001 x 2 + -0.001 x 3 + 0.243 x 4 + -0.016 x 5 + 0.019 x 6
# 398 component: 0.0% of initial variance
# -0.001 x 1 + 0.003 x 2 + -0.001 x 3 + 0.060 x 4 + 0.196 x 5 + -0.046 x 6
# 399 component: 0.0% of initial variance
# -0.001 x 1 + -0.000 x 2 + -0.001 x 3 + 0.077 x 4 + 0.008 x 5 + -0.012 x 6
# 400 component: 0.0% of initial variance
# -0.002 x 1 + 0.000 x 2 + 0.002 x 3 + -0.042 x 4 + 0.029 x 5 + 0.054 x 6
# 401 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + 0.000 x 3 + 0.001 x 4 + -0.031 x 5 + -0.011 x 6
# 402 component: 0.0% of initial variance
# 0.001 x 1 + -0.001 x 2 + -0.001 x 3 + 0.063 x 4 + -0.065 x 5 + -0.028 x 6
# 403 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + 0.001 x 3 + 0.004 x 4 + -0.014 x 5 + -0.008 x 6
# 404 component: 0.0% of initial variance
# 0.001 x 1 + 0.000 x 2 + 0.000 x 3 + 0.048 x 4 + 0.010 x 5 + 0.016 x 6
# 405 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + -0.001 x 3 + 0.134 x 4 + -0.016 x 5 + 0.012 x 6
# 406 component: 0.0% of initial variance
# -0.000 x 1 + 0.001 x 2 + -0.000 x 3 + -0.034 x 4 + -0.038 x 5 + 0.025 x 6
# 407 component: 0.0% of initial variance
# 0.002 x 1 + 0.000 x 2 + -0.000 x 3 + -0.020 x 4 + 0.004 x 5 + 0.019 x 6
# 408 component: 0.0% of initial variance
# 0.002 x 1 + 0.000 x 2 + -0.002 x 3 + -0.005 x 4 + 0.011 x 5 + -0.014 x 6
# 409 component: 0.0% of initial variance
# 0.001 x 1 + 0.001 x 2 + 0.000 x 3 + 0.025 x 4 + 0.003 x 5 + -0.018 x 6
# 410 component: 0.0% of initial variance
# 0.000 x 1 + -0.001 x 2 + -0.000 x 3 + 0.072 x 4 + 0.037 x 5 + 0.070 x 6
# 411 component: 0.0% of initial variance
# -0.001 x 1 + -0.001 x 2 + -0.000 x 3 + 0.041 x 4 + -0.022 x 5 + 0.023 x 6
# 412 component: 0.0% of initial variance
# 0.001 x 1 + 0.001 x 2 + 0.001 x 3 + -0.004 x 4 + 0.011 x 5 + 0.041 x 6
# 413 component: 0.0% of initial variance
# 0.000 x 1 + 0.001 x 2 + 0.000 x 3 + 0.028 x 4 + -0.028 x 5 + -0.078 x 6
# 414 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + -0.000 x 3 + 0.015 x 4 + 0.032 x 5 + 0.038 x 6
# 415 component: 0.0% of initial variance
# 0.000 x 1 + -0.001 x 2 + -0.000 x 3 + 0.019 x 4 + 0.012 x 5 + 0.042 x 6
# 416 component: 0.0% of initial variance
# -0.001 x 1 + -0.001 x 2 + -0.001 x 3 + -0.081 x 4 + -0.087 x 5 + -0.184 x 6
# 417 component: 0.0% of initial variance
# 0.001 x 1 + -0.001 x 2 + -0.001 x 3 + 0.003 x 4 + -0.065 x 5 + -0.054 x 6
# 418 component: 0.0% of initial variance
# -0.001 x 1 + -0.000 x 2 + 0.001 x 3 + -0.000 x 4 + 0.086 x 5 + -0.082 x 6
# 419 component: 0.0% of initial variance
# -0.000 x 1 + -0.001 x 2 + 0.001 x 3 + 0.008 x 4 + 0.009 x 5 + 0.000 x 6
# 420 component: 0.0% of initial variance
# 0.001 x 1 + -0.000 x 2 + 0.001 x 3 + 0.046 x 4 + 0.089 x 5 + 0.034 x 6
# 421 component: 0.0% of initial variance
# -0.000 x 1 + 0.001 x 2 + 0.000 x 3 + 0.034 x 4 + 0.021 x 5 + 0.036 x 6
# 422 component: 0.0% of initial variance
# 0.001 x 1 + 0.001 x 2 + 0.000 x 3 + 0.015 x 4 + -0.087 x 5 + 0.003 x 6
# 423 component: 0.0% of initial variance
# 0.000 x 1 + 0.000 x 2 + -0.001 x 3 + -0.003 x 4 + -0.186 x 5 + 0.095 x 6
# 424 component: 0.0% of initial variance
# -0.000 x 1 + 0.001 x 2 + -0.000 x 3 + 0.010 x 4 + -0.011 x 5 + 0.179 x 6
# 425 component: 0.0% of initial variance
# -0.000 x 1 + -0.001 x 2 + 0.000 x 3 + -0.059 x 4 + 0.043 x 5 + 0.019 x 6
# 426 component: 0.0% of initial variance
# -0.000 x 1 + -0.001 x 2 + 0.000 x 3 + -0.019 x 4 + 0.082 x 5 + -0.052 x 6
# 427 component: 0.0% of initial variance
# -0.001 x 1 + -0.000 x 2 + -0.001 x 3 + -0.128 x 4 + -0.057 x 5 + 0.108 x 6
# 428 component: 0.0% of initial variance
# 0.000 x 1 + -0.002 x 2 + -0.000 x 3 + -0.067 x 4 + 0.021 x 5 + 0.097 x 6
# 429 component: 0.0% of initial variance
# 0.000 x 1 + -0.001 x 2 + -0.001 x 3 + -0.117 x 4 + 0.171 x 5 + 0.004 x 6
# 430 component: 0.0% of initial variance
# 0.001 x 1 + -0.001 x 2 + 0.001 x 3 + 0.016 x 4 + 0.010 x 5 + -0.040 x 6
# 431 component: 0.0% of initial variance
# -0.001 x 1 + -0.001 x 2 + 0.001 x 3 + -0.024 x 4 + 0.057 x 5 + 0.006 x 6
# 432 component: 0.0% of initial variance
# -0.000 x 1 + 0.001 x 2 + 0.001 x 3 + 0.073 x 4 + 0.028 x 5 + -0.004 x 6
# 433 component: 0.0% of initial variance
# 0.000 x 1 + 0.001 x 2 + 0.001 x 3 + 0.023 x 4 + -0.022 x 5 + -0.001 x 6
# 434 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + 0.000 x 3 + 0.105 x 4 + 0.036 x 5 + 0.006 x 6
# 435 component: 0.0% of initial variance
# 0.000 x 1 + 0.001 x 2 + 0.001 x 3 + 0.161 x 4 + -0.034 x 5 + -0.021 x 6
# 436 component: 0.0% of initial variance
# 0.000 x 1 + 0.000 x 2 + 0.000 x 3 + -0.104 x 4 + -0.001 x 5 + 0.011 x 6
# 437 component: 0.0% of initial variance
# 0.001 x 1 + -0.000 x 2 + -0.001 x 3 + 0.078 x 4 + -0.004 x 5 + 0.006 x 6
# 438 component: 0.0% of initial variance
# 0.000 x 1 + 0.000 x 2 + -0.001 x 3 + -0.073 x 4 + 0.004 x 5 + -0.016 x 6
# 439 component: 0.0% of initial variance
# 0.005 x 1 + -0.001 x 2 + -0.001 x 3 + 0.084 x 4 + 0.027 x 5 + -0.001 x 6
# 440 component: 0.0% of initial variance
# 0.003 x 1 + -0.001 x 2 + -0.001 x 3 + 0.061 x 4 + 0.014 x 5 + 0.013 x 6
# 441 component: 0.0% of initial variance
# -0.001 x 1 + -0.001 x 2 + -0.001 x 3 + 0.049 x 4 + 0.052 x 5 + 0.028 x 6
# 442 component: 0.0% of initial variance
# 0.005 x 1 + -0.001 x 2 + -0.000 x 3 + 0.009 x 4 + -0.008 x 5 + -0.004 x 6
# 443 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + -0.000 x 3 + -0.003 x 4 + -0.001 x 5 + -0.003 x 6
# 444 component: 0.0% of initial variance
# 0.000 x 1 + 0.000 x 2 + -0.000 x 3 + 0.025 x 4 + 0.047 x 5 + 0.105 x 6
# 445 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + 0.000 x 3 + -0.012 x 4 + 0.011 x 5 + -0.058 x 6
# 446 component: 0.0% of initial variance
# 0.000 x 1 + 0.000 x 2 + -0.000 x 3 + 0.081 x 4 + 0.085 x 5 + 0.357 x 6
# 447 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + -0.001 x 3 + 0.064 x 4 + 0.017 x 5 + -0.212 x 6
# 448 component: 0.0% of initial variance
# -0.001 x 1 + 0.000 x 2 + -0.000 x 3 + 0.003 x 4 + -0.002 x 5 + 0.021 x 6
# 449 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + -0.000 x 3 + 0.040 x 4 + 0.106 x 5 + -0.126 x 6
# 450 component: 0.0% of initial variance
# 0.000 x 1 + 0.000 x 2 + -0.000 x 3 + 0.000 x 4 + 0.053 x 5 + -0.059 x 6
# 451 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + -0.000 x 3 + 0.001 x 4 + -0.071 x 5 + -0.266 x 6
# 452 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + 0.000 x 3 + -0.035 x 4 + 0.058 x 5 + 0.518 x 6
# 453 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + -0.000 x 3 + -0.017 x 4 + -0.006 x 5 + -0.248 x 6
# 454 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + -0.000 x 3 + 0.007 x 4 + 0.078 x 5 + -0.009 x 6
# 455 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + -0.000 x 3 + -0.067 x 4 + 0.054 x 5 + -0.022 x 6
# 456 component: 0.0% of initial variance
# 0.000 x 1 + 0.000 x 2 + -0.000 x 3 + 0.167 x 4 + 0.608 x 5 + -0.069 x 6
# 457 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + 0.000 x 3 + 0.563 x 4 + -0.114 x 5 + 0.028 x 6
# 458 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + 0.000 x 3 + -0.138 x 4 + 0.448 x 5 + -0.033 x 6
# 459 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + -0.000 x 3 + -0.321 x 4 + -0.018 x 5 + 0.004 x 6
# 460 component: 0.0% of initial variance
# 0.000 x 1 + 0.000 x 2 + 0.000 x 3 + -0.021 x 4 + -0.008 x 5 + 0.031 x 6
# 461 component: 0.0% of initial variance
# -0.000 x 1 + -0.000 x 2 + -0.000 x 3 + -0.215 x 4 + -0.083 x 5 + 0.007 x 6
# 462 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + -0.000 x 3 + -0.288 x 4 + -0.002 x 5 + 0.002 x 6
# 463 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + -0.000 x 3 + -0.065 x 4 + 0.006 x 5 + 0.016 x 6
# 464 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + -0.000 x 3 + -0.017 x 4 + -0.004 x 5 + -0.010 x 6
# 465 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + 0.000 x 3 + -0.001 x 4 + -0.003 x 5 + 0.001 x 6
# 466 component: 0.0% of initial variance
# 0.000 x 1 + 0.000 x 2 + 0.000 x 3 + -0.004 x 4 + 0.005 x 5 + 0.002 x 6
# 467 component: 0.0% of initial variance
# -0.000 x 1 + -0.000 x 2 + -0.000 x 3 + 0.001 x 4 + 0.002 x 5 + 0.001 x 6
# 468 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + -0.000 x 3 + 0.000 x 4 + 0.000 x 5 + 0.000 x 6
# 469 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + 0.000 x 3 + -0.000 x 4 + -0.000 x 5 + 0.000 x 6
# 470 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + -0.000 x 3 + 0.000 x 4 + 0.000 x 5 + 0.000 x 6
# 471 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + -0.000 x 3 + -0.000 x 4 + -0.000 x 5 + 0.000 x 6
# 472 component: 0.0% of initial variance
# 0.000 x 1 + 0.000 x 2 + -0.000 x 3 + -0.000 x 4 + 0.000 x 5 + 0.000 x 6
# 473 component: 0.0% of initial variance
# 0.000 x 1 + 0.000 x 2 + 0.000 x 3 + -0.000 x 4 + 0.000 x 5 + -0.000 x 6
# 474 component: 0.0% of initial variance
# -0.000 x 1 + -0.000 x 2 + -0.000 x 3 + 0.000 x 4 + 0.000 x 5 + -0.000 x 6
# 475 component: 0.0% of initial variance
# -0.000 x 1 + -0.000 x 2 + 0.000 x 3 + 0.000 x 4 + 0.000 x 5 + 0.000 x 6
# 476 component: 0.0% of initial variance
# -0.000 x 1 + -0.000 x 2 + 0.000 x 3 + -0.000 x 4 + -0.000 x 5 + -0.000 x 6
# 477 component: 0.0% of initial variance
# -0.000 x 1 + -0.000 x 2 + 0.000 x 3 + -0.000 x 4 + -0.000 x 5 + 0.000 x 6
# 478 component: 0.0% of initial variance
# 0.000 x 1 + 0.000 x 2 + 0.000 x 3 + 0.000 x 4 + 0.000 x 5 + 0.000 x 6
# 479 component: 0.0% of initial variance
# 0.000 x 1 + 0.000 x 2 + 0.000 x 3 + 0.000 x 4 + 0.000 x 5 + -0.000 x 6
# 480 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + 0.000 x 3 + -0.000 x 4 + 0.000 x 5 + 0.000 x 6
# 481 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + -0.000 x 3 + 0.000 x 4 + 0.000 x 5 + -0.000 x 6
# 482 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + -0.000 x 3 + 0.000 x 4 + 0.000 x 5 + -0.000 x 6
# 483 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + 0.000 x 3 + 0.000 x 4 + -0.000 x 5 + -0.000 x 6
# 484 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + 0.000 x 3 + 0.000 x 4 + 0.000 x 5 + 0.000 x 6
# 485 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + 0.000 x 3 + 0.000 x 4 + 0.000 x 5 + 0.000 x 6
# 486 component: 0.0% of initial variance
# -0.000 x 1 + -0.000 x 2 + 0.000 x 3 + -0.000 x 4 + 0.000 x 5 + -0.000 x 6
# 487 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + 0.000 x 3 + 0.000 x 4 + -0.000 x 5 + -0.000 x 6
# 488 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + -0.000 x 3 + 0.000 x 4 + 0.000 x 5 + -0.000 x 6
# 489 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + 0.000 x 3 + 0.000 x 4 + -0.000 x 5 + 0.000 x 6
# 490 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + 0.000 x 3 + -0.000 x 4 + 0.000 x 5 + -0.000 x 6
# 491 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + -0.000 x 3 + -0.000 x 4 + -0.000 x 5 + 0.000 x 6
# 492 component: 0.0% of initial variance
# 0.000 x 1 + 0.000 x 2 + 0.000 x 3 + -0.000 x 4 + 0.000 x 5 + 0.000 x 6
# 493 component: 0.0% of initial variance
# 0.000 x 1 + 0.000 x 2 + -0.000 x 3 + 0.000 x 4 + -0.000 x 5 + -0.000 x 6
# 494 component: 0.0% of initial variance
# 0.000 x 1 + 0.000 x 2 + -0.000 x 3 + 0.000 x 4 + 0.000 x 5 + -0.000 x 6
# 495 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + -0.000 x 3 + -0.000 x 4 + 0.000 x 5 + -0.000 x 6
# 496 component: 0.0% of initial variance
# 0.000 x 1 + 0.000 x 2 + -0.000 x 3 + 0.000 x 4 + -0.000 x 5 + -0.000 x 6
# 497 component: 0.0% of initial variance
# -0.000 x 1 + -0.000 x 2 + 0.000 x 3 + -0.000 x 4 + 0.000 x 5 + 0.000 x 6
# 498 component: 0.0% of initial variance
# -0.000 x 1 + -0.000 x 2 + 0.000 x 3 + 0.000 x 4 + -0.000 x 5 + 0.000 x 6
# 499 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + 0.000 x 3 + -0.000 x 4 + 0.000 x 5 + -0.000 x 6
# 500 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + -0.000 x 3 + -0.000 x 4 + 0.000 x 5 + 0.000 x 6
# 501 component: 0.0% of initial variance
# 0.000 x 1 + 0.000 x 2 + 0.000 x 3 + -0.000 x 4 + -0.000 x 5 + 0.000 x 6
# 502 component: 0.0% of initial variance
# 0.000 x 1 + 0.000 x 2 + -0.000 x 3 + -0.000 x 4 + 0.000 x 5 + -0.000 x 6
# 503 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + -0.000 x 3 + -0.000 x 4 + -0.000 x 5 + 0.000 x 6
# 504 component: 0.0% of initial variance
# -0.000 x 1 + -0.000 x 2 + -0.000 x 3 + 0.000 x 4 + 0.000 x 5 + 0.000 x 6
# 505 component: 0.0% of initial variance
# -0.000 x 1 + -0.000 x 2 + -0.000 x 3 + -0.000 x 4 + -0.000 x 5 + -0.000 x 6
# 506 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + -0.000 x 3 + 0.000 x 4 + 0.000 x 5 + 0.000 x 6
# 507 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + 0.000 x 3 + -0.000 x 4 + -0.000 x 5 + 0.000 x 6
# 508 component: 0.0% of initial variance
# 0.000 x 1 + 0.000 x 2 + 0.000 x 3 + -0.000 x 4 + -0.000 x 5 + 0.000 x 6
# 509 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + 0.000 x 3 + -0.000 x 4 + 0.000 x 5 + -0.000 x 6
# 510 component: 0.0% of initial variance
# -0.000 x 1 + -0.000 x 2 + -0.000 x 3 + 0.000 x 4 + 0.000 x 5 + -0.000 x 6
# 511 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + -0.000 x 3 + -0.000 x 4 + 0.000 x 5 + -0.000 x 6
# 512 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + -0.000 x 3 + 0.000 x 4 + -0.000 x 5 + 0.000 x 6
# 513 component: 0.0% of initial variance
# 0.000 x 1 + 0.000 x 2 + -0.000 x 3 + -0.000 x 4 + -0.000 x 5 + -0.000 x 6
# 514 component: 0.0% of initial variance
# -0.000 x 1 + -0.000 x 2 + 0.000 x 3 + -0.000 x 4 + 0.000 x 5 + -0.000 x 6
# 515 component: 0.0% of initial variance
# -0.000 x 1 + -0.000 x 2 + -0.000 x 3 + 0.000 x 4 + -0.000 x 5 + -0.000 x 6
# 516 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + -0.000 x 3 + 0.000 x 4 + 0.000 x 5 + -0.000 x 6
# 517 component: 0.0% of initial variance
# -0.000 x 1 + -0.000 x 2 + -0.000 x 3 + 0.000 x 4 + -0.000 x 5 + -0.000 x 6
# 518 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + 0.000 x 3 + 0.000 x 4 + 0.000 x 5 + -0.000 x 6
# 519 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + -0.000 x 3 + 0.000 x 4 + -0.000 x 5 + 0.000 x 6
# 520 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + 0.000 x 3 + 0.000 x 4 + -0.000 x 5 + 0.000 x 6
# 521 component: 0.0% of initial variance
# -0.000 x 1 + -0.000 x 2 + 0.000 x 3 + 0.000 x 4 + 0.000 x 5 + -0.000 x 6
# 522 component: 0.0% of initial variance
# -0.000 x 1 + -0.000 x 2 + 0.000 x 3 + -0.000 x 4 + 0.000 x 5 + -0.000 x 6
# 523 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + -0.000 x 3 + 0.000 x 4 + -0.000 x 5 + 0.000 x 6
# 524 component: 0.0% of initial variance
# -0.000 x 1 + -0.000 x 2 + -0.000 x 3 + 0.000 x 4 + -0.000 x 5 + 0.000 x 6
# 525 component: 0.0% of initial variance
# 0.000 x 1 + 0.000 x 2 + -0.000 x 3 + 0.000 x 4 + 0.000 x 5 + -0.000 x 6
# 526 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + -0.000 x 3 + 0.000 x 4 + 0.000 x 5 + -0.000 x 6
# 527 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + -0.000 x 3 + 0.000 x 4 + -0.000 x 5 + 0.000 x 6
# 528 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + -0.000 x 3 + 0.000 x 4 + -0.000 x 5 + 0.000 x 6
# 529 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + 0.000 x 3 + -0.000 x 4 + 0.000 x 5 + 0.000 x 6
# 530 component: 0.0% of initial variance
# 0.000 x 1 + 0.000 x 2 + -0.000 x 3 + 0.000 x 4 + 0.000 x 5 + 0.000 x 6
# 531 component: 0.0% of initial variance
# 0.000 x 1 + 0.000 x 2 + -0.000 x 3 + 0.000 x 4 + -0.000 x 5 + 0.000 x 6
# 532 component: 0.0% of initial variance
# -0.000 x 1 + -0.000 x 2 + -0.000 x 3 + 0.000 x 4 + -0.000 x 5 + -0.000 x 6
# 533 component: 0.0% of initial variance
# 0.000 x 1 + 0.000 x 2 + 0.000 x 3 + -0.000 x 4 + 0.000 x 5 + -0.000 x 6
# 534 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + 0.000 x 3 + -0.000 x 4 + -0.000 x 5 + -0.000 x 6
# 535 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + -0.000 x 3 + -0.000 x 4 + 0.000 x 5 + 0.000 x 6
# 536 component: 0.0% of initial variance
# -0.000 x 1 + -0.000 x 2 + 0.000 x 3 + 0.000 x 4 + -0.000 x 5 + -0.000 x 6
# 537 component: 0.0% of initial variance
# -0.000 x 1 + -0.000 x 2 + 0.000 x 3 + 0.000 x 4 + 0.000 x 5 + -0.000 x 6
# 538 component: 0.0% of initial variance
# 0.000 x 1 + 0.000 x 2 + 0.000 x 3 + -0.000 x 4 + -0.000 x 5 + 0.000 x 6
# 539 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + -0.000 x 3 + -0.000 x 4 + 0.000 x 5 + -0.000 x 6
# 540 component: 0.0% of initial variance
# -0.000 x 1 + -0.000 x 2 + -0.000 x 3 + 0.000 x 4 + 0.000 x 5 + -0.000 x 6
# 541 component: 0.0% of initial variance
# -0.000 x 1 + -0.000 x 2 + -0.000 x 3 + -0.000 x 4 + 0.000 x 5 + -0.000 x 6
# 542 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + -0.000 x 3 + 0.000 x 4 + -0.000 x 5 + -0.000 x 6
# 543 component: 0.0% of initial variance
# 0.000 x 1 + 0.000 x 2 + -0.000 x 3 + 0.000 x 4 + -0.000 x 5 + -0.000 x 6
# 544 component: 0.0% of initial variance
# -0.000 x 1 + -0.000 x 2 + 0.000 x 3 + -0.000 x 4 + 0.000 x 5 + -0.000 x 6
# 545 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + 0.000 x 3 + 0.000 x 4 + -0.000 x 5 + 0.000 x 6
# 546 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + -0.000 x 3 + 0.000 x 4 + 0.000 x 5 + 0.000 x 6
# 547 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + -0.000 x 3 + -0.000 x 4 + -0.000 x 5 + -0.000 x 6
# 548 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + 0.000 x 3 + -0.000 x 4 + -0.000 x 5 + 0.000 x 6
# 549 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + 0.000 x 3 + 0.000 x 4 + -0.000 x 5 + 0.000 x 6
# 550 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + 0.000 x 3 + 0.000 x 4 + 0.000 x 5 + 0.000 x 6
# 551 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + -0.000 x 3 + 0.000 x 4 + -0.000 x 5 + -0.000 x 6
# 552 component: 0.0% of initial variance
# 0.000 x 1 + 0.000 x 2 + 0.000 x 3 + -0.000 x 4 + -0.000 x 5 + 0.000 x 6
# 553 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + 0.000 x 3 + 0.000 x 4 + 0.000 x 5 + 0.000 x 6
# 554 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + 0.000 x 3 + -0.000 x 4 + 0.000 x 5 + 0.000 x 6
# 555 component: 0.0% of initial variance
# -0.000 x 1 + 0.000 x 2 + 0.000 x 3 + 0.000 x 4 + 0.000 x 5 + 0.000 x 6
# 556 component: 0.0% of initial variance
# -0.000 x 1 + -0.000 x 2 + 0.000 x 3 + 0.000 x 4 + 0.000 x 5 + 0.000 x 6
# 557 component: 0.0% of initial variance
# -0.000 x 1 + -0.000 x 2 + -0.000 x 3 + 0.000 x 4 + 0.000 x 5 + 0.000 x 6
# 558 component: 0.0% of initial variance
# -0.000 x 1 + -0.000 x 2 + -0.000 x 3 + -0.000 x 4 + 0.000 x 5 + 0.000 x 6
# 559 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + -0.000 x 3 + -0.000 x 4 + 0.000 x 5 + 0.000 x 6
# 560 component: 0.0% of initial variance
# -0.000 x 1 + -0.000 x 2 + 0.000 x 3 + -0.000 x 4 + -0.000 x 5 + 0.000 x 6
# 561 component: 0.0% of initial variance
# 0.000 x 1 + -0.000 x 2 + -0.000 x 3 + 0.000 x 4 + 0.000 x 5 + 0.000 x 6

# %%
plt.scatter?

# %% [markdown]
# Визуализируйте данные в проекции на первые две главные компоненты.

# %%
# Ваш код здесь
pca = decomposition.PCA(n_components=2)
X_reduced = pca.fit_transform(X)

print('Projecting %d-dimensional data to 2D' % X.shape[1])

plt.figure(figsize=(12,10))
#plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=y, 
#            edgecolor='none', alpha=0.7, s=40,
#            cmap=plt.cm.get_cmap('nipy_spectral', 10))
plt.scatter(X_reduced[:, 0],  X_reduced[:, 1], c=y, s=20, cmap='viridis');
#plt.colorbar()
plt.title('MNIST. PCA projection');
# Out:
# Projecting 561-dimensional data to 2D

# %% [markdown]
# **Вопрос 3:**<br>
# Если все получилось правильно, Вы увидите сколько-то кластеров, почти идеально отделенных друг от друга. Какие виды активности входят в эти кластеры?<br>
#
# **Ответ:**
# - 1 кластер: все 6 активностей
# - **2 кластера: (ходьба, подъем вверх по лестнице, спуск по лестнице) и (сидение, стояние, лежание)**
# - 3 кластера: (ходьба), (подъем вверх по лестнице, спуск по лестнице) и (сидение, стояние, лежание)
# - 6 кластеров

# %% [markdown]
# ------------------------------

# %% [markdown]
# Сделайте кластеризацию данных методом `KMeans`, обучив модель на данных со сниженной за счет PCA размерностью. В данном случае мы подскажем, что нужно искать именно 6 кластеров, но в общем случае мы не будем знать, сколько кластеров надо искать.
#
# Параметры:
#
# - **n_clusters** = n_classes (число уникальных меток целевого класса)
# - **n_init** = 100
# - **random_state** = RANDOM_STATE (для воспроизводимости результата)
#
# Остальные параметры со значениями по умолчанию.

# %%
from sklearn.cluster import KMeans

# %%
# Ваш код здесь
pca = decomposition.PCA(n_components=65)
X_reduced = pca.fit_transform(X)

kmeans = KMeans(n_clusters=6, n_init = 100, random_state=RANDOM_STATE).fit(X_reduced)
X_kmeans = kmeans.fit(X_reduced)

# %%
cluster_labels = kmeans.labels_

# %% [markdown]
# Визуализируйте данные в проекции на первые две главные компоненты. Раскрасьте точки в соответствии с полученными метками кластеров.

# %%
# Ваш код здесь
plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=cluster_labels, s=20,  cmap='viridis');

# %% [markdown]
# Посмотрите на соответствие между метками кластеров и исходными метками классов и на то, какие виды активностей алгоритм `KMeans` путает.

# %%
tab = pd.crosstab(y, cluster_labels, margins=True)
tab.index = ['ходьба', 'подъем вверх по лестнице', 
             'спуск по лестнице', 'сидение', 'стояние', 'лежание', 'все']
tab.columns = ['cluster' + str(i + 1) for i in range(6)] + ['все']
tab
# Out:
#                           cluster1  cluster2  cluster3  cluster4  cluster5  \
# ходьба                           0       153       704         0         0
# подъем вверх по лестнице         0        82      1168         0         0
# спуск по лестнице                0       456       187         0         0
# сидение                       1257         0         3       468        49
# стояние                       1240         0         0       666         0
# лежание                          0         0        12       172      1760
# все                           2497       691      2074      1306      1809
#
#                           cluster6    все
# ходьба                         865   1722
# подъем вверх по лестнице       294   1544
# спуск по лестнице              763   1406
# сидение                          0   1777
# стояние                          0   1906
# лежание                          0   1944
# все                           1922  10299

# %%
print ("ходьба", round(tab["cluster6"]["ходьба"]/tab["все"]["ходьба"], 3))
print ("подъем вверх по лестнице", round(tab["cluster3"]["подъем вверх по лестнице"]/tab["все"]["подъем вверх по лестнице"], 3))
print ("спуск по лестнице", round(tab["cluster6"]["спуск по лестнице"]/tab["все"]["спуск по лестнице"], 3))
print ("сидение", round(tab["cluster1"]["сидение"]/tab["все"]["сидение"], 3))
print ("стояние", round(tab["cluster1"]["стояние"]/tab["все"]["стояние"], 3))
print ("лежание", round(tab["cluster5"]["лежание"]/tab["все"]["лежание"], 3))
# Out:
# ходьба 0.502
# подъем вверх по лестнице 0.756
# спуск по лестнице 0.543
# сидение 0.707
# стояние 0.651
# лежание 0.905

# %% [markdown]
# Видим, что каждому классу (т.е. каждой активности) соответствуют несколько кластеров. Давайте посмотрим на максимальную долю объектов в классе, отнесенных к какому-то одному кластеру. Это будет простой метрикой, характеризующей, насколько легко класс отделяется от других при кластеризации.
#
# Пример: если для класса "спуск по лестнице", в котором 1406 объектов,  распределение кластеров такое:
#  - кластер 1 – 900
#  - кластер 3 – 500
#  - кластер 6 – 6,
#
# то такая доля будет 900 / 1406 $\approx$ 0.64.
#
#
# **Вопрос 4:**<br>
# Какой вид активности отделился от остальных лучше всего в терминах простой  метрики, описанной выше?<br>
#
# **Ответ:**
# - ходьба
# - стояние
# - спуск по лестнице
# - **нет верного ответа**     -----------------------------------                     **лежание 0.905**

# %% [markdown]
# Видно, что kMeans не очень хорошо отличает только активности друг от друга. Используйте метод локтя, чтобы выбрать оптимальное количество кластеров, смотрите на функцию $D(k)$, описанную в 7-ой [статье](https://habrahabr.ru/company/ods/blog/325654/) курса – "Выбор числа кластеров для kMeans". Параметры алгоритма и данные используем те же, что раньше, меняем только `n_clusters`.

# %%
# Ваш код здесь
inertia = []
for k in tqdm_notebook(range(1, n_classes + 1)):
    kmeans = KMeans(n_clusters=k, random_state=RANDOM_STATE).fit(X_reduced)
    inertia.append(np.sqrt(kmeans.inertia_))

# %%
inertia
plt.plot(range(1, n_classes + 1), inertia, marker='s');
plt.xlabel('$k$')
plt.ylabel('$J(C_k)$');

# %% [markdown]
# **Вопрос 5:**<br>
# Какое количество кластеров оптимально выбрать, согласно методу локтя?<br>
#
# **Ответ:**
# - 1
# - **2**
# - 3
# - 4

# %% [markdown]
# ------------------------

# %% [markdown]
# Попробуем еще один метод кластеризации, который описывался в статье – агломеративную кластеризацию.

# %%
ag = AgglomerativeClustering(n_clusters=n_classes, 
                             linkage='ward').fit(X_reduced)

# %% [markdown]
# Посчитайте Adjusted Rand Index (`sklearn.metrics`) для получившегося разбиения на кластеры и для `KMeans` с параметрами из задания к 4 вопросу.

# %%
print("ag", metrics.cluster.adjusted_rand_score(y, ag.labels_))
print("km", metrics.cluster.adjusted_rand_score(y, kmeans.labels_))
# Out:
# ag 0.497318063129
# km 0.46121058584

# %%
metrics.cluster.adjusted_rand_score?

# %% [markdown]
# **Вопрос 6:**<br>
# Отметьте все верные утверждения.<br>
#
# **Варианты:**
# - **ARI выражает сходство меток, полученных после кластеризации, с метками классов для одной и той же выборки, и чем больше значение этого индекса, тем лучше**
# - **Согласно ARI, KMeans справился с кластеризацией хуже, чем Agglomerative Clustering**
# - Для ARI не имеет значения, какие именно метки присвоены кластерам, имеет значение только разбиение объектов на кластеры
# - **В случае случайного разбиения на кластеры ARI будет близок к нулю**

# %% [markdown]
# -------------------------------

# %% [markdown]
# Можно заметить, что задача не очень хорошо решается именно как задача кластеризации, если выделять несколько кластеров (> 2). Давайте теперь решим задачу классификации, вспомнив, что данные у нас размечены.
#
# Для классификации используйте метод опорных векторов – класс `sklearn.svm.LinearSVC`. Мы в курсе отдельно не рассматривали этот алгоритм, но он очень известен, почитать про него можно, например, в материалах Евгения Соколова –  [тут](https://github.com/esokolov/ml-course-msu/blob/master/ML16/lecture-notes/Sem11_linear.pdf).
#
# Настройте для `LinearSVC` гиперпараметр `C` с помощью `GridSearchCV`.
#
# - Обучите новый `StandardScaler` на обучающей выборке (со всеми исходными признаками), примените масштабирование к тестовой выборке
# - В `GridSearchCV` укажите  cv=3.

# %%
# Ваш код здесь
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %%
svc = LinearSVC(random_state=RANDOM_STATE)
svc_params = {'C': [0.001, 0.01, 0.1, 1, 10]}

# %%
# Ваш код здесь
best_svc = GridSearchCV(svc, svc_params, cv=3, n_jobs=-1, verbose=True)
best_svc.fit(X_train_scaled, y_train)
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:   12.5s finished
# GridSearchCV(cv=3, error_score='raise',
#        estimator=LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=17, tol=0.0001,
#      verbose=0),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'C': [0.001, 0.01, 0.1, 1, 10]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=True)

# %%
best_svc.best_params_
best_svc.best_score_
# Out:
# 0.93824809575625678

# %% [markdown]
# **Вопрос 7**<br>
# Какое значение гиперпараметра `C` было выбрано лучшим по итогам кросс-валидации?<br>
#
# **Ответ:**
# - 0.001
# - 0.01
# - **0.1**
# - 1
# - 10

# %%
y_predicted = best_svc.predict(X_test_scaled)

# %%
tab = pd.crosstab(y_test, y_predicted, margins=True)
tab.index = ['ходьба', 'подъем вверх по лестнице', 'спуск по лестнице', 
             'сидение', 'стояние', 'лежание', 'все']
tab.columns = ['ходьба', 'подъем вверх по лестнице', 'спуск по лестнице', 
               'сидение', 'стояние', 'лежание', 'все']
tab
# Out:
#                           ходьба  подъем вверх по лестнице  спуск по лестнице  \
# ходьба                       479                        11                  4
# подъем вверх по лестнице       4                       465                  1
# спуск по лестнице              1                         2                416
# сидение                        0                         4                  0
# стояние                        0                         0                  0
# лежание                        0                         0                  0
# все                          484                       482                421
#
#                           сидение  стояние  лежание   все
# ходьба                          2        0        0   496
# подъем вверх по лестнице        1        0        0   471
# спуск по лестнице               1        0        0   420
# сидение                       433       52        2   491
# стояние                        16      516        0   532
# лежание                         0        6      531   537
# все                           453      574      533  2947

# %% [markdown]
# Как видим, задача классификации решается неплохо.

# %%
#2 кластера: (ходьба, подъем вверх по лестнице, спуск по лестнице) и (сидение, стояние, лежание)

# %% [markdown]
# **Вопрос 8:**<br>
# Путает ли SVM классы внутри выделенных нами ранее (в задании к 3 вопросу) группах активностей? Считаем, что путает, если хотя бы в одном случае алгоритм ошибся.<br>
#
# **Ответ:**
# - **да**
# - нет

# %%
scaler = StandardScaler()
pca = decomposition.PCA(n_components=65, random_state=RANDOM_STATE)

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

X_train_sc_pca = pca.fit_transform(X_train_scaled)
X_test_sc_pca = pca.fit_transform(X_test_scaled)

# %%
svc2 = LinearSVC(random_state=RANDOM_STATE)
svc_params = {'C': [0.001, 0.01, 0.1, 1, 10]}
best_svc2 = GridSearchCV(svc, svc_params, cv=3, n_jobs=-1, verbose=False)
best_svc2.fit(X_train_sc_pca, y_train)
best_svc2.best_params_
# Out:
# {'C': 1}

# %%
y_predicted = best_svc2.predict(X_test_sc_pca)
best_svc2.best_score_
# Out:
# 0.89961915125136016

# %%
print(best_svc.best_score_, best_svc2.best_score_)
print(round((best_svc.best_score_ - best_svc2.best_score_)*100))
# Out:
# 0.938248095756 0.899619151251
# 4.0

# %% [markdown]
# Наконец, проделайте то же самое, что в 7 вопросе, только добавив PCA.
#
# - Используйте выборки `X_train_scaled` и `X_test_scaled`
# - Используйте тот же PCA, что раньше (сохранить надо 90% дисперсии), обучите его на отмасшабированной обучающей выборке, примените преобразование к тестовой
# - Настройте гиперпараметр `C` на кросс-валидации по обучающей выборке с PCA-преобразованием. Вы заметите, насколько это проходит быстрее, чем раньше.
#
# **Вопрос 9:**<br>
# Какова разность между лучшим качеством (долей верных ответов) на кросс-валидации в случае всех 561 исходных признаков и во втором случае, когда применялся метод главных компонент? Округлите до целых процентов.<br>
#
# **Варианты:**
# - Качество одинаковое
# - 2%
# - **4% **
# - 10%
# - 20%

# %% [markdown]
# **Вопрос 10:**<br>
# Выберите все верные утверждения:
#
# **Варианты:**
# - Метод главных компонент в данном случае позволил уменьшить время обучения модели, при этом качество (доля верных ответов на кросс-валидации) очень пострадало, более чем на 10%
# - **PCA можно использовать для визуализации данных, однако для этой задачи есть и лучше подходящие методы, например, tSNE. Зато PCA имеет меньшую вычислительную сложность**
# - **PCA строит линейные комбинации исходных признаков, которые плохо интерпретируются человеком**
# - **SVM работает лучше, чем kMeans, поскольку этот алгоритм явно сводится к задаче оптимизации**
